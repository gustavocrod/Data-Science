# %% [markdown]
# # Acidentes de trânsito na *highway* brasileira (BR)
#
# A Polícia Rodoviária Federal - PRF (Anteriormente com a denominação "Polícia das Estradas") foi criada pelo presidente Washington Luís no [Decreto nº 18.323, de 24 de Julho de 1928](https://www2.camara.leg.br/legin/fed/decret/1920-1929/decreto-18323-24-julho-1928-516789-publicacaooriginal-1-pe.html#:~:text=DECRETA%3A,conformidade%20com%20o%20decreto%20n.) - que definia as regras de trânsito daquele tempo.
#
# Com o advento da Constituição brasileira de 1998, a PRF foi instituicionalizada e integrada ao Sistema Nacional de Segurança Publica. Inserino no Art. 144, do Título V - Da Defesa do Estado e das Instituições Democráticas, Capítulo III - Da Segurança Pública, a PRF definitivamente ganhou o status permanente de uma instituição Estatal, agindo no policiamento e inspecionamento de rodoviais e áreas de interesse da União.
#
# A sede da PRF estão localizadas em Brasília, Distrito Federal. Atualmente, há 27 divisões regionais que estão responsáveis por inspecionar e policiar mais de 70000km de rodovias federais e várias áreas de interesse da União.
#
# Sua missão é "Promover a prosperidade da Naão e garantir a segurança pública e mobilidade no Brasil".
#
# (Texto retirado e adaptado do [website da Polícia Rodoviária Federal](https://www.gov.br/prf/pt-br/acesso-a-informacao/institucional-1]))
#
# ### Aquisição dos dados
# Os conjuntos de dados correspondem ao período de 2007 a 2020 e foram disponibilizados através da [plataforma Kaggle](https://www.kaggle.com/mcamera/brazil-highway-traffic-accidents). Estes foram extraídos diretamente do [website da PRF](https://www.gov.br/prf/pt-br/acesso-a-informacao/dados-abertos/dados-abertos-acidentes),
#
# Esses dados são divididos em arquivos .CSV anuais e o ultimo arquivo (ano atual) é atualizado mensalmente.
#
# Os dados são disponibilizados em 3 grupos:
#
# 1. Agrupados por ocorrencia - (arquivos como datatranANO.csv)
# 2. Agrupados por pessoa - (arquivos como acidentesANO.csv)
# 3. Agrupados por pessoa - Todas as causas e tipos de acidentes (a partir de 2017) - (arquivos como acidentesANO\_todascausas\_tipos)
#
# Os dados são provenientes dos sistemas BR-Brasil e Boletim de Acidente de Trânsito (BAT), com as seguintes considerações:
# * O sistema BR-Brasil foi usado em nivel nacional entre 2007 a 2016. Os acidentes foram armazenados usando o sistema BR-Brasil. Nesse sistema o policial responsável pela ocorrencia insere os dados relacionados aos involvidos, localização, veículos e a dinâmica do acidente.
#
# * A partir de janeiro de 2017, o sistema BR-Brasil foi descontinuado e a PRF começou a utilizar um novo sistema para armazenar as ocorrências de acidentes, o sistema BAT.
#
#
# ## *Definir o escopo do trabalho aqui*

# %% [markdown]
# **Importação das Bibliotecas**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **1. Análise exploratória**
#
# ###  **Carregamento dos Arquivos**

# %%
dataframe2007= pd.read_csv('archive/por_ocorrencias/datatran2007.csv', sep='\;', engine='python', encoding='latin-1')
dataframe2008= pd.read_csv('archive/por_ocorrencias/datatran2008.csv', sep='\;', engine='python', encoding='latin-1')
dataframe2009= pd.read_csv('archive/por_ocorrencias/datatran2009.csv', sep='\;', engine='python', encoding='latin-1')
dataframe2010= pd.read_csv('archive/por_ocorrencias/datatran2010.csv', sep='\;', engine='python', encoding='latin-1')
dataframe2011= pd.read_csv('archive/por_ocorrencias/datatran2011.csv', sep='\;', engine='python', encoding='latin-1')

#a partir do csv de 2012 até 2020 os nomes de colunas e os valores ficaram entre aspas duplas (" ")
dataframe2012= pd.read_csv('archive/por_ocorrencias/datatran2012.csv', sep='\;', engine='python', encoding='latin-1')
dataframe2013= pd.read_csv('archive/por_ocorrencias/datatran2013.csv', sep='\;', engine='python', encoding='latin-1')
dataframe2014= pd.read_csv('archive/por_ocorrencias/datatran2014.csv', sep='\;', engine='python', encoding='latin-1')
dataframe2015= pd.read_csv('archive/por_ocorrencias/datatran2015.csv', sep='\;', engine='python', encoding='latin-1')
dataframe2016= pd.read_csv('archive/por_ocorrencias/datatran2016.csv', sep='\;', engine='python', encoding='latin-1')

#a partir do csv de 2017 até 2020 algumas colunas mudaram(adicionaram 5 colunas no final)
dataframe2017= pd.read_csv('archive/por_ocorrencias/datatran2017.csv', sep='\;', engine='python', encoding='latin-1')
dataframe2018= pd.read_csv('archive/por_ocorrencias/datatran2018.csv', sep='\;', engine='python', encoding='latin-1')
dataframe2019= pd.read_csv('archive/por_ocorrencias/datatran2019.csv', sep='\;', engine='python', encoding='latin-1')
dataframe2020= pd.read_csv('archive/por_ocorrencias/datatran2020.csv', sep='\;', engine='python', encoding='latin-1')

# %% [markdown]
# ### **Visualização original dos DataFrames**

# %%
dataframe2010.head().T
# Out:
#                                               0                        1  \
# id                                      1000329                  1000837
# data_inversa                         29/10/2010               14/12/2010
# dia_semana                                Sexta                    Terça
# horario                                14:20:00                 22:00:00
# uf                                           RS                       SP
# br                                          285                      116
# km                                        397.3                    406.5
# municipio                  SANTA BARBARA DO SUL                 MIRACATU
# causa_acidente          Velocidade incompatível                   Outras
# tipo_acidente                    Saída de Pista  Colisão com objeto fixo
# classificacao_acidente              Sem Vítimas              Sem Vítimas
# fase_dia                              Pleno dia              Plena noite
# sentido_via                           Crescente                Crescente
# condicao_metereologica                    Chuva                    Chuva
# tipo_pista                              Simples                    Dupla
# tracado_via                               Curva                     Reta
# uso_solo                                  Rural                    Rural
# ano                                        2010                     2010
# pessoas                                       5                        1
# mortos                                        0                        0
# feridos_leves                                 0                        0
# feridos_graves                                0                        0
# ilesos                                        5                        1
# ignorados                                     0                        0
# feridos                                       0                        0
# veiculos                                      1                        1
#
#                                               2                        3  \
# id                                      1002150                  1003283
# data_inversa                         07/03/2010               26/10/2010
# dia_semana                              Domingo                    Terça
# horario                                16:00:00                 14:20:00
# uf                                           BA                       BA
# br                                          407                      116
# km                                        220.8                      567
# municipio                          CAPIM GROSSO             NOVA ITARANA
# causa_acidente          Velocidade incompatível                   Outras
# tipo_acidente                       Capotamento  Colisão com objeto fixo
# classificacao_acidente      Com Vítimas Feridas              Sem Vítimas
# fase_dia                              Pleno dia                Pleno dia
# sentido_via                         Decrescente                Crescente
# condicao_metereologica                    Chuva                Ceu Claro
# tipo_pista                              Simples                 Múltipla
# tracado_via                                Reta                     Reta
# uso_solo                                  Rural                    Rural
# ano                                        2010                     2010
# pessoas                                       3                        1
# mortos                                        0                        0
# feridos_leves                                 0                        0
# feridos_graves                                2                        0
# ilesos                                        1                        1
# ignorados                                     0                        0
# feridos                                       2                        0
# veiculos                                      1                        1
#
#                                               4
# id                                      1004212
# data_inversa                         15/09/2010
# dia_semana                               Quarta
# horario                                12:30:00
# uf                                           SE
# br                                          101
# km                                          107
# municipio                         SAO CRISTOVAO
# causa_acidente                 Falta de atenção
# tipo_acidente           Colisão com objeto fixo
# classificacao_acidente      Com Vítimas Feridas
# fase_dia                              Pleno dia
# sentido_via                         Decrescente
# condicao_metereologica                Ceu Claro
# tipo_pista                              Simples
# tracado_via                                Reta
# uso_solo                                  Rural
# ano                                        2010
# pessoas                                       2
# mortos                                        0
# feridos_leves                                 2
# feridos_graves                                0
# ilesos                                        0
# ignorados                                     0
# feridos                                       2
# veiculos                                      1

# %%
dataframe2012.head().T
# Out:
#                                                   0                      1  \
# "id"                                      "1035523"              "1035527"
# "data_inversa"                           2012-01-01             2012-01-01
# "dia_semana"                              "Domingo"              "Domingo"
# "horario"                                "15:45:00"             "03:00:00"
# "uf"                                           "SC"                   "SC"
# "br"                                          "282"                  "280"
# "km"                                        "513.7"                  "188"
# "municipio"                                 "XAXIM"                "MAFRA"
# "causa_acidente"          "Velocidade incompatível"   "Ingestão de álcool"
# "tipo_acidente"                    "Saída de Pista"      "Colisão lateral"
# "classificacao_acidente"      "Com Vítimas Feridas"  "Com Vítimas Feridas"
# "fase_dia"                              "Pleno dia"          "Plena noite"
# "sentido_via"                           "Crescente"            "Crescente"
# "condicao_metereologica"                      "Sol"                "Chuva"
# "tipo_pista"                              "Simples"              "Simples"
# "tracado_via"                               "Curva"                "Curva"
# "uso_solo"                                  "Rural"                "Rural"
# "ano"                                          2012                   2012
# "pessoas"                                         2                      3
# "mortos"                                          0                      0
# "feridos_leves"                                   1                      1
# "feridos_graves"                                  0                      0
# "ilesos"                                          1                      2
# "ignorados"                                       0                      0
# "feridos"                                         1                      1
# "veiculos"                                        1                      2
#
#                                                   2                      3  \
# "id"                                      "1035528"              "1035530"
# "data_inversa"                           2012-01-01             2012-01-01
# "dia_semana"                              "Domingo"              "Domingo"
# "horario"                                "05:40:00"             "06:00:00"
# "uf"                                           "SC"                   "RO"
# "br"                                          "116"                  "364"
# "km"                                          "1.5"                "616.5"
# "municipio"                                 "MAFRA"      "ITAPUÃ DO OESTE"
# "causa_acidente"          "Velocidade incompatível"               "Outras"
# "tipo_acidente"           "Colisão com objeto fixo"       "Saída de Pista"
# "classificacao_acidente"              "Sem Vítimas"  "Com Vítimas Feridas"
# "fase_dia"                            "Plena noite"            "Pleno dia"
# "sentido_via"                           "Crescente"            "Crescente"
# "condicao_metereologica"                    "Chuva"             "Ignorada"
# "tipo_pista"                              "Simples"              "Simples"
# "tracado_via"                          "Cruzamento"                 "Reta"
# "uso_solo"                                 "Urbano"                "Rural"
# "ano"                                          2012                   2012
# "pessoas"                                         1                      1
# "mortos"                                          0                      0
# "feridos_leves"                                   0                      1
# "feridos_graves"                                  0                      0
# "ilesos"                                          1                      0
# "ignorados"                                       0                      0
# "feridos"                                         0                      1
# "veiculos"                                        1                      1
#
#                                                                      4
# "id"                                                         "1035533"
# "data_inversa"                                              2012-01-01
# "dia_semana"                                                 "Domingo"
# "horario"                                                   "16:30:00"
# "uf"                                                              "RJ"
# "br"                                                             "101"
# "km"                                                              "47"
# "municipio"                                    "CAMPOS DOS GOYTACAZES"
# "causa_acidente"                                  "Ingestão de álcool"
# "tipo_acidente"           "Queda de motocicleta / bicicleta / veículo"
# "classificacao_acidente"                         "Com Vítimas Feridas"
# "fase_dia"                                               "Plena noite"
# "sentido_via"                                            "Decrescente"
# "condicao_metereologica"                                       "Chuva"
# "tipo_pista"                                                 "Simples"
# "tracado_via"                                                   "Reta"
# "uso_solo"                                                     "Rural"
# "ano"                                                             2012
# "pessoas"                                                            1
# "mortos"                                                             0
# "feridos_leves"                                                      1
# "feridos_graves"                                                     0
# "ilesos"                                                             0
# "ignorados"                                                          0
# "feridos"                                                            1
# "veiculos"                                                           1

# %%
dataframe2017.head().T
# Out:
#                                                        0  \
# "id"                                                   8
# "data_inversa"                                2017-01-01
# "dia_semana"                                   "domingo"
# "horario"                                     "00:00:00"
# "uf"                                                "PR"
# "br"                                                 376
# "km"                                                 112
# "municipio"                                  "PARANAVAI"
# "causa_acidente"                 "Fenômenos da Natureza"
# "tipo_acidente"           "Queda de ocupante de veículo"
# "classificacao_acidente"           "Com Vítimas Feridas"
# "fase_dia"                                 "Plena Noite"
# "sentido_via"                                "Crescente"
# "condicao_metereologica"                         "Chuva"
# "tipo_pista"                                   "Simples"
# "tracado_via"                                     "Reta"
# "uso_solo"                                         "Não"
# "pessoas"                                              1
# "mortos"                                               0
# "feridos_leves"                                        0
# "feridos_graves"                                       1
# "ilesos"                                               0
# "ignorados"                                            0
# "feridos"                                              1
# "veiculos"                                             1
# "latitude"                                  -23,09880731
# "longitude"                                 -52,38789369
# "regional"                                       "SR-PR"
# "delegacia"                                     "DEL7/7"
# "uop"                                         "UOP05/PR"
#
#                                                       1  \
# "id"                                                  9
# "data_inversa"                               2017-01-01
# "dia_semana"                                  "domingo"
# "horario"                                    "00:01:00"
# "uf"                                               "SC"
# "br"                                                101
# "km"                                                234
# "municipio"                                   "PALHOCA"
# "causa_acidente"          "Falta de Atenção à Condução"
# "tipo_acidente"           "Colisão com objeto estático"
# "classificacao_acidente"                  "Sem Vítimas"
# "fase_dia"                                "Plena Noite"
# "sentido_via"                               "Crescente"
# "condicao_metereologica"                        "Chuva"
# "tipo_pista"                                    "Dupla"
# "tracado_via"                                   "Curva"
# "uso_solo"                                        "Não"
# "pessoas"                                             1
# "mortos"                                              0
# "feridos_leves"                                       0
# "feridos_graves"                                      0
# "ilesos"                                              1
# "ignorados"                                           0
# "feridos"                                             0
# "veiculos"                                            1
# "latitude"                                     -27,8101
# "longitude"                                    -48,6357
# "regional"                                      "SR-SC"
# "delegacia"                                    "DEL8/1"
# "uop"                                        "UOP02/SC"
#
#                                                    2  \
# "id"                                              11
# "data_inversa"                            2017-01-01
# "dia_semana"                               "domingo"
# "horario"                                 "00:00:00"
# "uf"                                            "PR"
# "br"                                             153
# "km"                                            56,9
# "municipio"               "SANTO ANTONIO DA PLATINA"
# "causa_acidente"                  "Animais na Pista"
# "tipo_acidente"                        "Capotamento"
# "classificacao_acidente"       "Com Vítimas Feridas"
# "fase_dia"                             "Plena Noite"
# "sentido_via"                          "Decrescente"
# "condicao_metereologica"            "Garoa/Chuvisco"
# "tipo_pista"                               "Simples"
# "tracado_via"                                 "Reta"
# "uso_solo"                                     "Não"
# "pessoas"                                          2
# "mortos"                                           0
# "feridos_leves"                                    2
# "feridos_graves"                                   0
# "ilesos"                                           0
# "ignorados"                                        0
# "feridos"                                          2
# "veiculos"                                         1
# "latitude"                              -23,36951985
# "longitude"                             309,93513107
# "regional"                                   "SR-PR"
# "delegacia"                                 "DEL7/7"
# "uop"                                     "UOP07/PR"
#
#                                                                   3  \
# "id"                                                             12
# "data_inversa"                                           2017-01-01
# "dia_semana"                                              "domingo"
# "horario"                                                "00:00:00"
# "uf"                                                           "GO"
# "br"                                                            153
# "km"                                                            435
# "municipio"                                              "ANAPOLIS"
# "causa_acidente"          "Avarias e/ou desgaste excessivo no pneu"
# "tipo_acidente"                                        "Tombamento"
# "classificacao_acidente"                      "Com Vítimas Feridas"
# "fase_dia"                                            "Plena Noite"
# "sentido_via"                                         "Decrescente"
# "condicao_metereologica"                                "Céu Claro"
# "tipo_pista"                                                "Dupla"
# "tracado_via"                                                "Reta"
# "uso_solo"                                                    "Sim"
# "pessoas"                                                         1
# "mortos"                                                          0
# "feridos_leves"                                                   0
# "feridos_graves"                                                  1
# "ilesos"                                                          0
# "ignorados"                                                       0
# "feridos"                                                         1
# "veiculos"                                                        1
# "latitude"                                             -16,27473677
# "longitude"                                            -48,96908998
# "regional"                                                  "SR-GO"
# "delegacia"                                                "DEL1/2"
# "uop"                                                    "UOP01/GO"
#
#                                                     4
# "id"                                               13
# "data_inversa"                             2017-01-01
# "dia_semana"                                "domingo"
# "horario"                                  "00:00:00"
# "uf"                                             "SC"
# "br"                                              280
# "km"                                             77,3
# "municipio"                                  "CORUPA"
# "causa_acidente"                 "Ingestão de Álcool"
# "tipo_acidente"           "Saída de leito carroçável"
# "classificacao_acidente"        "Com Vítimas Feridas"
# "fase_dia"                              "Plena Noite"
# "sentido_via"                           "Decrescente"
# "condicao_metereologica"                      "Chuva"
# "tipo_pista"                                "Simples"
# "tracado_via"                         "Não Informado"
# "uso_solo"                                      "Não"
# "pessoas"                                           1
# "mortos"                                            0
# "feridos_leves"                                     1
# "feridos_graves"                                    0
# "ilesos"                                            0
# "ignorados"                                         0
# "feridos"                                           1
# "veiculos"                                          1
# "latitude"                               -26,44675249
# "longitude"                              -49,20166969
# "regional"                                    "SR-SC"
# "delegacia"                                  "DEL8/6"
# "uop"                                      "UOP03/SC"

# %% [markdown]
# # **Normalização dos dados dos dataframes**

# %%
#normalização dos nomes das colunas dos dataframe 2012, 2013, 2014 e 2015 (retirar as ""):
dataframe2012.columns= dataframe2012.columns.str.replace('"','')
dataframe2013.columns= dataframe2013.columns.str.replace('"','')
dataframe2014.columns= dataframe2014.columns.str.replace('"','')
dataframe2015.columns= dataframe2015.columns.str.replace('"','')

#lista de colunas a serem normalizadas no for
seri= dataframe2012[['id','dia_semana', 'horario','uf','br','km', 'municipio',
                     'causa_acidente','tipo_acidente','classificacao_acidente',
                     'fase_dia','sentido_via','condicao_metereologica',
                     'tipo_pista','tracado_via','uso_solo']]

#normalização do dataframe 2012, 2013, 2014 e 2015 (retirar as "" que estavam nos dados de várias colunas):
for i in seri:
    dataframe2012[i]= dataframe2012[i].str.replace('"','')
    dataframe2013[i]= dataframe2013[i].str.replace('"','')
    dataframe2014[i]= dataframe2014[i].str.replace('"','')
    dataframe2015[i]= dataframe2015[i].str.replace('"','')
    
#dataframe2012.head()
#dataframe2013.head()
#dataframe2014.head()
#dataframe2015.head()

# %%
#normalização dos nomes das colunas dos dataframe 2016 (retirar as ""):
dataframe2016.columns= dataframe2016.columns.str.replace('"','')

#lista de colunas a serem normalizadas no for
seri= dataframe2016[['data_inversa','dia_semana','horario','uf','km', 'municipio',
                     'causa_acidente','tipo_acidente','classificacao_acidente',
                     'fase_dia','sentido_via','condicao_metereologica',
                     'tipo_pista','tracado_via','uso_solo']]

#normalização do dataframe 2016 (retirar as "" que estavam nos dados de várias colunas):
for i in seri:
    dataframe2016[i]= dataframe2016[i].str.replace('"','')

#dataframe2016.head()

# %%
#normalização dos nomes das colunas dos dataframe 2017, 2018, 2019 e 2020 (retirar as ""):
dataframe2017.columns= dataframe2017.columns.str.replace('"','')
dataframe2018.columns= dataframe2018.columns.str.replace('"','')
dataframe2019.columns= dataframe2019.columns.str.replace('"','')
dataframe2020.columns= dataframe2020.columns.str.replace('"','')

#lista de colunas a serem normalizadas no for
seri= dataframe2017[['dia_semana', 'horario','uf', 'municipio',
                     'causa_acidente','tipo_acidente','classificacao_acidente',
                     'fase_dia','sentido_via','condicao_metereologica',
                     'tipo_pista','tracado_via','uso_solo','regional','delegacia','uop']]

#normalização do dataframe 2017, 2018, 2019 e 2020 (retirar as "" que estavam nos dados de várias colunas):
for i in seri:
    dataframe2017[i]= dataframe2017[i].str.replace('"','')
    dataframe2018[i]= dataframe2018[i].str.replace('"','')
    dataframe2019[i]= dataframe2019[i].str.replace('"','')
    dataframe2020[i]= dataframe2020[i].str.replace('"','')

#dataframe2017.head()
#dataframe2018.head()
#dataframe2019.head()
#dataframe2020.head()

# %%
dataframe2017.dtypes
# Out:
# id                          int64
# data_inversa               object
# dia_semana                 object
# horario                    object
# uf                         object
# br                        float64
# km                         object
# municipio                  object
# causa_acidente             object
# tipo_acidente              object
# classificacao_acidente     object
# fase_dia                   object
# sentido_via                object
# condicao_metereologica     object
# tipo_pista                 object
# tracado_via                object
# uso_solo                   object
# pessoas                     int64
# mortos                      int64
# feridos_leves               int64
# feridos_graves              int64
# ilesos                      int64
# ignorados                   int64
# feridos                     int64
# veiculos                    int64
# latitude                   object
# longitude                  object
# regional                   object
# delegacia                  object
# uop                        object
# dtype: object

# %%
dataframe2017['tipo_pista'].value_counts()
# Out:
# Simples     46344
# Dupla       37242
# Múltipla     5977
# Name: tipo_pista, dtype: int64

# %%
dataframe2017['causa_acidente'].value_counts()
# Out:
# Falta de Atenção à Condução                                                       34508
# Velocidade Incompatível                                                           10432
# Ingestão de Álcool                                                                 6448
# Não guardar distância de segurança                                                 5837
# Desobediência às normas de trânsito pelo condutor                                  5219
# Defeito Mecânico no Veículo                                                        4649
# Pista Escorregadia                                                                 4253
# Condutor Dormindo                                                                  3798
# Animais na Pista                                                                   2623
# Falta de Atenção do Pedestre                                                       2390
# Ultrapassagem Indevida                                                             2054
# Avarias e/ou desgaste excessivo no pneu                                            1588
# Defeito na Via                                                                     1422
# Mal Súbito                                                                          972
# Restrição de Visibilidade                                                           884
# Objeto estático sobre o leito carroçável                                            769
# Carga excessiva e/ou mal acondicionada                                              545
# Fenômenos da Natureza                                                               442
# Sinalização da via insuficiente ou inadequada                                       414
# Deficiência ou não Acionamento do Sistema de Iluminação/Sinalização do Veículo      235
# Ingestão de Substâncias Psicoativas                                                  78
# Agressão Externa                                                                      2
# Desobediência às normas de trânsito pelo pedestre                                     1
# Name: causa_acidente, dtype: int64

# %%
dataframe2017['classificacao_acidente'].value_counts()
# Out:
# Com Vítimas Feridas    53699
# Sem Vítimas            30681
# Com Vítimas Fatais      5183
# Name: classificacao_acidente, dtype: int64

# %%
dataframe2017['dia_semana'].value_counts()
# Out:
# sábado           15174
# domingo          14784
# sexta-feira      13849
# segunda-feira    12175
# quinta-feira     11787
# quarta-feira     11029
# terça-feira      10765
# Name: dia_semana, dtype: int64

# %%
dataframe2017['uso_solo'].value_counts()
# Out:
# Não    52863
# Sim    36700
# Name: uso_solo, dtype: int64

# %%
### latitude e longite para plot
dataframe2017['latitude']  = dataframe2017['latitude'].str.replace(',','.')
dataframe2017['longitude']  = dataframe2017['longitude'].str.replace(',','.')

# %%
dataframe2017['latitude'] = dataframe2017['latitude'].astype(float)
dataframe2017['longitude'] = dataframe2017['longitude'].astype(float)

# %% [markdown]
# # **Limpeza dos dados dos dataframes**

# %%
#tem colunas com dados faltantes ou incompletos

# %% [markdown]
# # **Normalização dos tipos de dados de cada coluna dos dataframes**

# %%
#a maioria está em string e precisa estar em formato data ou numérico

# %% [markdown]
# # **Visualização dos Dataframes já normalizados**

# %%
#dataframe2007.head()
dataframe2008.head()
#dataframe2009.head()
#dataframe2010.head()
#dataframe2011.head()
#dataframe2012.head()
#dataframe2013.head()
#dataframe2014.head()
#dataframe2015.head()
#dataframe2016.head()
#dataframe2017.head()
#dataframe2018.head()
#dataframe2019.head()
#dataframe2020.head()
# Out:
#         id data_inversa dia_semana   horario  uf   br     km  \
# 0  1012870   25/11/2008      Terça  16:00:00  DF   70      5
# 1  1023692   09/11/2008    Domingo  10:10:00  MA  316    284
# 2  1027252   27/11/2008     Quinta  09:20:00  PE  101   47.6
# 3  1029670   11/01/2008      Sexta  22:00:00  MA  316  432.1
# 4  1038085   07/05/2008     Quarta  07:05:00  RO  364  719.6
#
#                 municipio          causa_acidente        tipo_acidente  ...  \
# 0                BRASILIA                  Outras     Colisão traseira  ...
# 1  BELA VISTA DO MARANHAO                  Outras           Tombamento  ...
# 2                IGARASSU        Falta de atenção     Colisão traseira  ...
# 3                PERITORO  Ultrapassagem indevida      Colisão frontal  ...
# 4             PORTO VELHO        Falta de atenção  Colisão Transversal  ...
#
#   uso_solo   ano pessoas mortos feridos_leves feridos_graves ilesos  \
# 0   Urbano  2008       3      0             1              0      2
# 1    Rural  2008      12      2             7              2      1
# 2   Urbano  2008       4      0             2              0      2
# 3    Rural  2008       4      2             2              0      0
# 4   Urbano  2008       3      0             2              0      1
#
#    ignorados  feridos  veiculos
# 0          0        1         2
# 1          0        9         1
# 2          0        2         3
# 3          0        2         2
# 4          0        2         2
#
# [5 rows x 26 columns]

# %% [markdown]
# # **Perguntas:**
