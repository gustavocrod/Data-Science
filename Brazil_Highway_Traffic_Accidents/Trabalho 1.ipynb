# %% [markdown]
# # Acidentes de trânsito na *highway* brasileira (BR)
#
# A Polícia Rodoviária Federal - PRF (Anteriormente com a denominação "Polícia das Estradas") foi criada pelo presidente Washington Luís no [Decreto nº 18.323, de 24 de Julho de 1928](https://www2.camara.leg.br/legin/fed/decret/1920-1929/decreto-18323-24-julho-1928-516789-publicacaooriginal-1-pe.html#:~:text=DECRETA%3A,conformidade%20com%20o%20decreto%20n.) - que definia as regras de trânsito daquele tempo.
#
# Com o advento da Constituição brasileira de 1998, a PRF foi instituicionalizada e integrada ao Sistema Nacional de Segurança Publica. Inserino no Art. 144, do Título V - Da Defesa do Estado e das Instituições Democráticas, Capítulo III - Da Segurança Pública, a PRF definitivamente ganhou o status permanente de uma instituição Estatal, agindo no policiamento e inspecionamento de rodoviais e áreas de interesse da União.
#
# A sede da PRF estão localizadas em Brasília, Distrito Federal. Atualmente, há 27 divisões regionais que estão responsáveis por inspecionar e policiar mais de 70000km de rodovias federais e várias áreas de interesse da União.
#
# Sua missão é "Promover a prosperidade da Naão e garantir a segurança pública e mobilidade no Brasil".
#
# (Texto retirado e adaptado do [website da Polícia Rodoviária Federal](https://www.gov.br/prf/pt-br/acesso-a-informacao/institucional-1]))
#
# ### Aquisição dos dados
# Os conjuntos de dados correspondem ao período de 2007 a 2020 e foram disponibilizados através da [plataforma Kaggle](https://www.kaggle.com/mcamera/brazil-highway-traffic-accidents). Estes foram extraídos diretamente do [website da PRF](https://www.gov.br/prf/pt-br/acesso-a-informacao/dados-abertos/dados-abertos-acidentes),
#
# Esses dados são divididos em arquivos .CSV anuais e o ultimo arquivo (ano atual) é atualizado mensalmente.
#
# Os dados são disponibilizados em 3 grupos:
#
# 1. Agrupados por ocorrencia - (arquivos como datatranANO.csv)
# 2. Agrupados por pessoa - (arquivos como acidentesANO.csv)
# 3. Agrupados por pessoa - Todas as causas e tipos de acidentes (a partir de 2017) - (arquivos como acidentesANO\_todascausas\_tipos)
#
# Os dados são provenientes dos sistemas BR-Brasil e Boletim de Acidente de Trânsito (BAT), com as seguintes considerações:
# * O sistema BR-Brasil foi usado em nivel nacional entre 2007 a 2016. Os acidentes foram armazenados usando o sistema BR-Brasil. Nesse sistema o policial responsável pela ocorrencia insere os dados relacionados aos involvidos, localização, veículos e a dinâmica do acidente.
#
# * A partir de janeiro de 2017, o sistema BR-Brasil foi descontinuado e a PRF começou a utilizar um novo sistema para armazenar as ocorrências de acidentes, o sistema BAT.
#
#
# ### *overview* dos dados por ocorrência
#
# **De 2007 até 2016:**
#
# | Nome da variável       | Descricao                                                                                                     |
# |------------------------|---------------------------------------------------------------------------------------------------------------|
# | id                     | Variável com valores numéricos, representando o identificador do acidente                                     |
# | data_inversa           | Data da ocorrência no formato dd/mm/aaaa.                                                                     |
# | dia_semana             | Dia da semana da ocorrência. Ex.: Segunda, Terça, etc                                                         |
# | horario                | Horário da ocorrência no formato hh:mm:ss.                                                                    |
# | uf                     | Unidade da Federação. Ex.: MG, PE, DF, etc.                                                                   |
# | br                     | Variável com valores numéricos representando o identificador da BR do acidente                                |
# | municipio              | Nome do município de ocorrência do acidente.                                                                  |
# | causa_acidente         | Identificação da causa presumível do acidente. Ex.: Falta de atenção, Velocidade incompatível, etc.           |
# | tipo_acidente          | Identificação do tipo de acidente. Ex.: Colisão frontal, Saída de pista,etc                                   |
# | classificação_acidente | Classificação quanto à gravidade do acidente: Sem Vítimas, Com Vítimas Feridas, Com Vítimas Fatais e Ignorado |
# | fase_dia               | Fase do dia no momento do acidente. Ex. Amanhecer, Pleno dia, etc.                                            |
# | sentido_via            | Sentido da via considerando o ponto de colisão: Crescente e decrescente.                                      |
# | condição_meteorologica | Condição meteorológica no momento do acidente: Céu claro, chuva,vento,etc.                                    |
# | tipo_pista             | Tipo da pista considerando a quantidade de faixas:Dupla,simples ou múltipla.                                  |
# | tracado_via            | Descrição do traçado da via: reta, curva ou cruzamento.                                                       |
# | uso_solo               | Descrição sobre as características do local do acidente: Urbano ou rural.                                     |
# | pessoas                | Total de pessoas envolvidas na ocorrência.                                                                    |
# | mortos                 | Total de pessoas mortas envolvidas na ocorrência.                                                             |
# | feridos_leves          | Total de pessoas com ferimentos leves envolvidas na ocorrência.                                               |
# | feridos_graves         | Total de pessoas com ferimentos graves envolvidas na ocorrência.                                              |
# | Ilesos                 | Total de pessoas ilesas envolvidas na ocorrência.                                                             |
# | Ignorados              | Total de pessoas envolvidas na ocorrência e que não se soube o estado físico.                                 |
# | feridos                | Total de pessoas feridas envolvidas na ocorrência (é a soma dos feridos leves com os graves).                 |
# | veiculos               | Total de veículos envolvidos na ocorrência.                                                                   |
#
# **De 2017 até 2020:**
# Acréscimo dos seguintes campos
#
# | Nome da variável       | Descricao                                                                                                     |
# |------------------------|---------------------------------------------------------------------------------------------------------------|
# | latitude                     | Latitude do local do acidente em formato geodésico decimal.                                    |
# | longitude           | Longitude do local do acidente em formato geodésico decimal
# | regional               | Código da regional da PRF.                                                                   |
# | delegacia               | Código da delegacia que registrou a ocorrência.                                                                   |
# | uop               | --- |                                                                   |
#
#
# ### *Algumas questões / hipóteses pertinentes sobre os dados*
#
# **Questões informativas/descritivas**
#
#  - #1 Quais dias da semana em que ocorrem mais acidentes em todo Brasil?
#
#  - #2 Quais meses ocorreram mais acidentes em todo Brasil?
#
#  - #3 Que tipos de acidentes tem maior ocorrência em todo Brasil?
#
#  - #4 Quais causas levaram a ocorrer mais acidentes no Brasil?
#
#  - #5 Que tipos de veículos mais se envolvem em acidentes? (motocicletas, automóveis ou caminhões)
#
#  - #6 Quais as marcas de veículos que se envolvem em acidentes por falha mecânica?
#
#  - #7 Veículos novos ou antigos se envolvem em mais acidentes?
#
#  - #8 Onde e em que condições precisamos ter mais atenção no trânsito?
#
#  - #9 Qual a faixa etária que mais se envolve em acidente?
#
#  - #10 Quais as causas de acidentes com maior taxa de mortalidade?
#
#
# **Hipoteses**
#
#  - #1 Os "horários de pico" são mais perigosos para transitar? Os horários diurnos são mais perigosos para transitar do que nos períodos noturnos?
#
#  - #2 Vésperas de datas comemorativas possuem um maior índice de acidentes (Brasil e RS).
#
#  - #3 A faixa etária de 20 - 30 anos é que mais se envolve em acidente causado por consumo alcoólico.

# %% [markdown]
# **Importação das Bibliotecas**

# %%
import pandas as pd
import numpy as np
from numpy import nan as NA

import matplotlib.pyplot as plt
import seaborn as sns

#plt.rc('figure', figsize=(5, 5))

# %% [markdown]
# # **1. Análise exploratória**

# %% [markdown]
# ###  **Carregamento dos Arquivos:**
#
# **OBS:** os Data Frame df_pessoas_'ano' são Data Frames de complemento para os dados dos Data Frames df_ocorrencia_'ano'
#
# a partir do ano de 2017 até 2020 teve acréscimo de geolocalização das tabelas

# %% [markdown]
# - **Base de dados por ocorrência:**

# %%
df_ocorrencia_2007= pd.read_csv('archive/por_ocorrencias/datatran2007.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos'])
df_ocorrencia_2008= pd.read_csv('archive/por_ocorrencias/datatran2008.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos'])
df_ocorrencia_2009= pd.read_csv('archive/por_ocorrencias/datatran2009.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos'])
df_ocorrencia_2010= pd.read_csv('archive/por_ocorrencias/datatran2010.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos'])
df_ocorrencia_2011= pd.read_csv('archive/por_ocorrencias/datatran2011.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos'])
df_ocorrencia_2012= pd.read_csv('archive/por_ocorrencias/datatran2012.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos'])
df_ocorrencia_2013= pd.read_csv('archive/por_ocorrencias/datatran2013.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos'])
df_ocorrencia_2014= pd.read_csv('archive/por_ocorrencias/datatran2014.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos'])
df_ocorrencia_2015= pd.read_csv('archive/por_ocorrencias/datatran2015.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos'])
df_ocorrencia_2016= pd.read_csv('archive/por_ocorrencias/datatran2016.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos'])
df_ocorrencia_2017= pd.read_csv('archive/por_ocorrencias/datatran2017.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos','latitude','longitude'])
df_ocorrencia_2018= pd.read_csv('archive/por_ocorrencias/datatran2018.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos','latitude','longitude'])
df_ocorrencia_2019= pd.read_csv('archive/por_ocorrencias/datatran2019.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos','latitude','longitude'])
df_ocorrencia_2020= pd.read_csv('archive/por_ocorrencias/datatran2020.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','data_inversa','dia_semana','horario','uf','br','causa_acidente','tipo_acidente','fase_dia','condicao_metereologica','tracado_via','uso_solo','pessoas','mortos','feridos_leves','feridos_graves','ilesos','feridos','veiculos','latitude','longitude'])

# %% [markdown]
# - **Base de dados por pessoas:**

# %%
df_pessoas_2007= pd.read_csv('archive/por_pessoas/acidentes2007.csv', sep=',', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2008= pd.read_csv('archive/por_pessoas/acidentes2008.csv', sep=',', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2009= pd.read_csv('archive/por_pessoas/acidentes2009.csv', sep=',', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2010= pd.read_csv('archive/por_pessoas/acidentes2010.csv', sep=',', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2011= pd.read_csv('archive/por_pessoas/acidentes2011.csv', sep=',', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2012= pd.read_csv('archive/por_pessoas/acidentes2012.csv', sep=',', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2013= pd.read_csv('archive/por_pessoas/acidentes2013.csv', sep=',', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2014= pd.read_csv('archive/por_pessoas/acidentes2014.csv', sep=',', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2015= pd.read_csv('archive/por_pessoas/acidentes2015.csv', sep=',', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2016= pd.read_csv('archive/por_pessoas/acidentes2016.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2017= pd.read_csv('archive/por_pessoas/acidentes2017.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2018= pd.read_csv('archive/por_pessoas/acidentes2018.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2019= pd.read_csv('archive/por_pessoas/acidentes2019.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])
df_pessoas_2020= pd.read_csv('archive/por_pessoas/acidentes2020.csv', sep=';', engine='python', encoding='latin-1', usecols=['id','pesid','id_veiculo','tipo_veiculo','marca','ano_fabricacao_veiculo','tipo_envolvido','estado_fisico','idade','sexo'])

# %% [markdown]
# # 2. Limpeza e Normalização dos Data Frames

# %% [markdown]
# - **Adicionar coluna "ano" em todos os dataframes:**
# Como alguns arquivos .csv vieram com ano e outros não, quando foi carregado os arquivos, optamos por não carregar o ano, mas sim fazer esta definição neste momento.

# %%
df_pessoas_2007['ano']= 2007
df_pessoas_2008['ano']= 2008
df_pessoas_2009['ano']= 2009
df_pessoas_2010['ano']= 2010
df_pessoas_2011['ano']= 2011
df_pessoas_2012['ano']= 2012
df_pessoas_2013['ano']= 2013
df_pessoas_2014['ano']= 2014
df_pessoas_2015['ano']= 2015
df_pessoas_2016['ano']= 2016
df_pessoas_2017['ano']= 2017
df_pessoas_2018['ano']= 2018
df_pessoas_2019['ano']= 2019
df_pessoas_2020['ano']= 2020

df_ocorrencia_2007['ano']= 2007
df_ocorrencia_2008['ano']= 2008
df_ocorrencia_2009['ano']= 2009
df_ocorrencia_2010['ano']= 2010
df_ocorrencia_2011['ano']= 2011
df_ocorrencia_2012['ano']= 2012
df_ocorrencia_2013['ano']= 2013
df_ocorrencia_2014['ano']= 2014
df_ocorrencia_2015['ano']= 2015
df_ocorrencia_2016['ano']= 2016
df_ocorrencia_2017['ano']= 2017
df_ocorrencia_2018['ano']= 2018
df_ocorrencia_2019['ano']= 2019
df_ocorrencia_2020['ano']= 2020

# %% [markdown]
# - **Concatenar todos os DataFrames "por ocorrencia" e "por pessoas" para dois DataFrames principais:**

# %%
dataframe_ocorrencia= pd.concat([df_ocorrencia_2007,df_ocorrencia_2008,df_ocorrencia_2009,df_ocorrencia_2010,
                                 df_ocorrencia_2011,df_ocorrencia_2012,df_ocorrencia_2013,df_ocorrencia_2014,
                                 df_ocorrencia_2015,df_ocorrencia_2016,df_ocorrencia_2017,df_ocorrencia_2018,
                                 df_ocorrencia_2019,df_ocorrencia_2020], sort = False)

dataframe_pessoa= pd.concat([df_pessoas_2007,df_pessoas_2008,df_pessoas_2009,df_pessoas_2010,df_pessoas_2011,
                              df_pessoas_2012,df_pessoas_2013,df_pessoas_2014,df_pessoas_2015,df_pessoas_2016,
                              df_pessoas_2017,df_pessoas_2018,df_pessoas_2019,df_pessoas_2020], sort = False)

# %% [markdown]
# - **Eliminar linhas duplicadas dos DataFrames:**

# %%
dataframe_ocorrencia.drop_duplicates(inplace= True)
dataframe_pessoa.drop_duplicates(inplace= True)

# %% [markdown]
# - **Eliminar linhas com todos os valores incompletos ou nulos:**

# %%
dataframe_ocorrencia.dropna(how='all', inplace= True)
dataframe_pessoa.dropna(how='all', inplace= True)

# %% [markdown]
# - **Reindexar os íncides dos dois DataFrames:**

# %%
#reindexar os índices do dataframe pessoa
dataframe_pessoa.index= range(len(dataframe_pessoa))
#dataframe_pessoa

#reindexar os índices do dataframe ocorrencia
dataframe_ocorrencia.index= range(len(dataframe_ocorrencia))
#dataframe_ocorrencia

# %% [markdown]
# - **Normalização das colunas do Data Frame de pessoa:**

# %%
#já prontos

#coluna 'id'(id do acidente):
dataframe_pessoa.id= dataframe_pessoa.id.astype(np.int64)


#coluna 'pesid'(id da pessoa):
#valores nulos viraram -1 e foi alterado o tipo de dado da coluna para int64
dataframe_pessoa.pesid.isnull().value_counts()
dataframe_pessoa.pesid[dataframe_pessoa.pesid.isnull()==True]= -1
dataframe_pessoa.pesid= dataframe_pessoa.pesid.astype(np.int64)
#dataframe_pessoa.pesid.value_counts()


#coluna 'id_veiculo'(id dos veículos):
#normalizado os campos (null) para número -1, retirado espaços em branco, dados 'Na' viraram -1, 
#tipo de dado da coluna alterado para int64
dataframe_pessoa.id_veiculo= dataframe_pessoa.id_veiculo.str.replace('(','')
dataframe_pessoa.id_veiculo= dataframe_pessoa.id_veiculo.str.replace(')','')
dataframe_pessoa.id_veiculo= dataframe_pessoa.id_veiculo.str.replace(' ','')
dataframe_pessoa.id_veiculo= dataframe_pessoa.id_veiculo.str.replace('null','-1')
dataframe_pessoa.id_veiculo.fillna(-1, inplace=True)
dataframe_pessoa.id_veiculo= dataframe_pessoa.id_veiculo.astype(np.int64)
#dataframe_pessoa.id_veiculo.value_counts()


#coluna 'tipo_veiculo'(tipo de veículos):
#normalizado os campos(null) para 'Não Informado', alterado nomes parecidos para um só tipo
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('(','')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace(')','')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('null','Não Informado')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Microônibus','Micro-ônibus')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Trator de esteiras','Trator de esteira')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Caminhão-Trator','Caminhão')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Caminhão-trator','Caminhão')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Não identificado','Não Informado')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Semireboque','Semi-reboque')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Semi-Reboque','Semi-reboque')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Caminhão-Tanque','Caminhão')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Trator de rodas','Trator')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Trator de esteira','Trator')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Trator misto','Trator')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Carroça-charrete','Carroça')
dataframe_pessoa.tipo_veiculo= dataframe_pessoa.tipo_veiculo.str.replace('Carro-de-mao','Carro de mão')
dataframe_pessoa.tipo_veiculo.value_counts()




#coluna 'estado_fisico'(estado físico da pessoa envolvida):
#alterado nomes parecidos para um só tipo, alterar valor (null) para 'Ileso', 
#limpado os espcaços em branco no inicio e fim das palavras pois estava dando nomes diferentes
seri= pd.Series(dataframe_pessoa.estado_fisico)
seri= seri.str.strip()
dataframe_pessoa.estado_fisico= seri
dataframe_pessoa.estado_fisico= dataframe_pessoa.estado_fisico.str.replace('(','')
dataframe_pessoa.estado_fisico= dataframe_pessoa.estado_fisico.str.replace(')','')
dataframe_pessoa.estado_fisico= dataframe_pessoa.estado_fisico.str.replace('Lesões Leves','Ferido Leve')
dataframe_pessoa.estado_fisico= dataframe_pessoa.estado_fisico.str.replace('Lesões Graves','Ferido Grave')
dataframe_pessoa.estado_fisico= dataframe_pessoa.estado_fisico.str.replace('Morto','Óbito')
dataframe_pessoa.estado_fisico= dataframe_pessoa.estado_fisico.str.replace('null','Ileso')
dataframe_pessoa.estado_fisico= dataframe_pessoa.estado_fisico.str.replace('Ignorado','Ileso')
dataframe_pessoa.estado_fisico= dataframe_pessoa.estado_fisico.str.replace('Não Informado','Ileso')
#dataframe_pessoa.estado_fisico.value_counts()


#coluna 'tipo_envolvido'(quem se envolveu no acidente):
#dataframe_pessoa.tipo_envolvido.value_counts()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Condutor                 3168175
# Passageiro                758223
# Pedestre                   64922
# Testemunha                 12760
# Cavaleiro                    920
# Vítima                       182
# Autor                         12
# Ciclista                       9
# Não Informado                  4
# Proprietário de Carga          1
# Proprietário da CNH            1
# Name: tipo_envolvido, dtype: int64

# %%
#coluna 'marca'(marca e modelo dos veículos): falta arrumar
#alguns nomes de marcas estão sem '/' e precisa colocar para depois a expressão regular funcionar certo
#retirar espaços em branco no inicio e fim das palavras
#normalizar nomes de fabricantes para padrões corretos

seri= pd.Series(dataframe_pessoa.marca)
seri= seri.str.strip()
dataframe_pessoa.marca= seri

#CHEVROLET
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/GM','CHEVROLET/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/CHEVROLET','CHEVROLET/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('CHEV/','CHEVROLET/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('GM/','CHEVROLET/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/GM','CHEVROLET/')


#TOYOTA
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/TOYOTA','TOYOTA/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/TOYOTA','TOYOTA/')


#VOLKSWAGEN
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/VW','VOLKSWAGEN/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('VW/','VOLKSWAGEN/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/VW','VOLKSWAGEN/')


#FIAT
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/FIAT','FIAT/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/FIAT','FIAT/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/IVECOFIAT','FIAT/IVECO')


#KIA
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/KIA','KIA/')


#CITROEN
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/CITROEN','CITROEN/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/CETROEN','CITROEN/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/CITROEN','CITROEN/')


#FORD
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/FORD','FORD/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('M.A./FORD','FORD/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/FORD','FORD/')


#RENAULT
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/RENAULT','RENAULT/')


#PEUGEOT



#HYUNDAI
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/HYUNDAI','HYUNDAI/')


#MERCEDES-BENZ
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/M.BENZ','MERCEDES-BENZ/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('MBENZ/','MERCEDES-BENZ/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('M.BENZ/','MERCEDES-BENZ/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('M.B./','MERCEDES-BENZ/')


#AUDI
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/AUDI','AUDI/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/AUDI','AUDI/')


#MITSUBISHI MOTORS
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('MMC/','MITSUBISHI MOTORS/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/MMC','MITSUBISHI MOTORS/')


#SUZUKI
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/SUZUKI','SUZUKI/')


#YAMAHA
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/YAMAHA','YAMAHA/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/YAMAHA','YAMAHA/')


#HONDA
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('H/HONDA','HONDA/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/HONDA','HONDA/')


#BMW
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/BMW','BMW/')


#SCANIA
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/SCANIA','SCANIA/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/SCANIA','SCANIA/')


#VOLVO



dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('(','')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace(')','')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('null','Não Informado')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('*************************','Não Informado')

dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('MA/MASSEY','MASSEY FERGUSON/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/JAGUAR','JAGUAR/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/PORSCHE','PORSCHE/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/SHAANXI','SHAANXI/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/KAWAZAKI','KAWAZAKI/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('IMP/CHRYSLER','CHRYSLER/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/IVECO','IVECO/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('REB/FORTCAR','FORTCAR/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/PEUGEOT','PEUGEOT/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/NISSAN','NISSAN/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('JTA/SUZUKI','SUZUKI/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/VOLVO','VOLVO/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/SHINERAY','SHINERAY/')
dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('I/JAC','JAC/')
#dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('null','NãoInformado')
#dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('null','NãoInformado')
#dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('null','NãoInformado')
#dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('null','NãoInformado')





#coluna 'ano_fabricacao_veiculo'(ano de fabricação dos veículos): falta arrumar
#dataframe_pessoa.ano_fabricacao_veiculo.value_counts()



#coluna 'idade'(idade da pessoa):
#dataframe_pessoas.idade= dataframe_pessoas.idade.astype(np.int32)
#dataframe_pessoas

#coluna 'sexo'(sexo da pessoa)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-97-e670f2c88d45> in <module>
#     108 dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace(')','')
#     109 dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('null','Não Informado')
# --> 110 dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('*************************','Não Informado')
#     111
#     112 dataframe_pessoa.marca= dataframe_pessoa.marca.str.replace('MA/MASSEY','MASSEY FERGUSON/')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in replace(self, pat, repl, n, case, flags, regex)
#    2532     def replace(self, pat, repl, n=-1, case=None, flags=0, regex=True):
#    2533         result = str_replace(self._parent, pat, repl, n=n, case=case,
# -> 2534                              flags=flags, regex=regex)
#    2535         return self._wrap_result(result)
#    2536
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in str_replace(arr, pat, repl, n, case, flags, regex)
#     567         if is_compiled_re or len(pat) > 1 or flags or callable(repl):
#     568             n = n if n >= 0 else 0
# --> 569             compiled = re.compile(pat, flags=flags)
#     570             f = lambda x: compiled.sub(repl=repl, string=x, count=n)
#     571         else:
#
# C:\ProgramData\Anaconda3\lib\re.py in compile(pattern, flags)
#     232 def compile(pattern, flags=0):
#     233     "Compile a regular expression pattern, returning a Pattern object."
# --> 234     return _compile(pattern, flags)
#     235
#     236 def purge():
#
# C:\ProgramData\Anaconda3\lib\re.py in _compile(pattern, flags)
#     284     if not sre_compile.isstring(pattern):
#     285         raise TypeError("first argument must be string or compiled pattern")
# --> 286     p = sre_compile.compile(pattern, flags)
#     287     if not (flags & DEBUG):
#     288         if len(_cache) >= _MAXCACHE:
#
# C:\ProgramData\Anaconda3\lib\sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# --> 764         p = sre_parse.parse(p, flags)
#     765     else:
#     766         pattern = None
#
# C:\ProgramData\Anaconda3\lib\sre_parse.py in parse(str, flags, pattern)
#     928
#     929     try:
# --> 930         p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, 0)
#     931     except Verbose:
#     932         # the VERBOSE flag was switched on inside the pattern.  to be
#
# C:\ProgramData\Anaconda3\lib\sre_parse.py in _parse_sub(source, state, verbose, nested)
#     424     while True:
#     425         itemsappend(_parse(source, state, verbose, nested + 1,
# --> 426                            not nested and not items))
#     427         if not sourcematch("|"):
#     428             break
#
# C:\ProgramData\Anaconda3\lib\sre_parse.py in _parse(source, state, verbose, nested, first)
#     649             if not item or item[0][0] is AT:
#     650                 raise source.error("nothing to repeat",
# --> 651                                    source.tell() - here + len(this))
#     652             if item[0][0] in _REPEATCODES:
#     653                 raise source.error("multiple repeat",
#
# error: nothing to repeat at position 0

# %%
lista= list(dataframe_pessoa.marca.value_counts().index)
lista[1000:2000]
# Out:
# ['FIAT/ PALIO ATTRACT 1.4',
#  'MERCEDES-BENZ/ATEGO 1725',
#  'CHEVROLET/ CAPTIVA SPORT FWD',
#  'VOLKSWAGEN/SAVEIRO CS TL MB',
#  'MAN/TGX 29.440 6X4 T',
#  'CITROEN/ C4 PALLAS20GAF',
#  'VOLKSWAGEN/GOL TL MB S',
#  'VOLKSWAGEN/GOL 16V SPORT',
#  'VOLKSWAGEN/7.110 S',
#  'VOLKSWAGEN/ GOL 1.6',
#  'RENAULT/LOGAN EXPR 1016V',
#  'FIAT/ SIENA EX',
#  'RENAULT/CLIO EXP 10 16VH',
#  'VOLKSWAGEN/7.100',
#  'FIAT/DOBLO HLX 1.8 FLEX',
#  'CHEVROLET/VECTRA SEDAN',
#  'VOLKSWAGEN/16.200',
#  'VOLVO/FH 500 6X4T',
#  'MITSUBISHI MOTORS/L200 SPORT 4X4 GLS',
#  'RENAULT/SCENIC AUT 1616V',
#  'TOYOTA/ETIOS SD XS',
#  'HONDA/ 150',
#  'CHEVROLET/ASTRA EXPRESSION',
#  'VOLKSWAGEN/SANTANA GLS 2000',
#  'VOLKSWAGEN/23.210 MOTOR CUMMINS',
#  'CHEVROLET/MONZA CLUB',
#  'KIA/ CERATO EX2 1.6L',
#  'MERCEDES-BENZ/BUSSCAR EL BUSS R',
#  'VOLKSWAGEN/ AMAROK CD 4X4 TREND',
#  'MERCEDES-BENZ/L 1621',
#  'VOLKSWAGEN/GOL TREND',
#  'MERCEDES-BENZ/L 1317',
#  'IVECO/STRALISHD 490S38TN',
#  'MERCEDES-BENZ/ 415CDISPRINTERM',
#  'VOLKSWAGEN/31.320 CNC 6X4',
#  'VOLKSWAGEN/PARATI 1.6 CITY',
#  'CHEVROLET/S10 COLINA S',
#  'I/TRAXX JL50Q 2',
#  'FORD/ RANGER XLT 13D',
#  'IVECO/DAILY55C16 CS',
#  'CITROEN/XSARA PICASSO EX',
#  'MITSUBISHI MOTORS/ L200 TRITON',
#  'VOLKSWAGEN/GOL SPECIAL MB',
#  'RENAULT/MASTER EUROLAF P',
#  'CHEVROLET/MONZA CLASSIC SE',
#  'MERCEDES-BENZ/L1113 TOPLINE',
#  'CHEVROLET/S10 DELUXE',
#  'IVECO/CURSOR 450E33T',
#  'FIAT/STRADA 1.5',
#  'HONDA/NXR160 BROS ESD',
#  'FIAT/DUCATO 15',
#  'CITROEN/C3 EXCL 16 16V',
#  'CHEVROLET/CHEVROLET C10',
#  'CHEVROLET/VECTRA HATCH 4P GT-X',
#  'TOYOTA/ HILUX CDSRVA4FD',
#  'VOLKSWAGEN/ SPACEFOX GII',
#  'FIAT/ UNO I.E',
#  'VOLKSWAGEN/10.160 DRC 4X2',
#  'SCANIA/MPOLO PARADISO LD',
#  'FORD/CARGO 2429',
#  'RENAULT/SCENIC RT1.6 16V',
#  'FIAT/PALIO WK TREKK 1.6',
#  'CITROEN/JUMPER M33M 23S',
#  'FIAT/ELBA WEEKEND IE',
#  'MERCEDES-BENZ/1318',
#  'YAMAHA/YBR150 FACTOR ED',
#  'CHEVROLET/VERANEIO',
#  'CHEVROLET/ CORSA GL',
#  'VOLKSWAGEN/GOLF FLASH',
#  'FIAT/ SIENA EL',
#  'IVECO/STRALIHD 450S38TN1',
#  'VOLKSWAGEN/SAVEIRO CL 1.8',
#  'MITSUBISHI MOTORS/PAJERO TR4 FLEX',
#  'NISSAN/ FRONTIER SEL',
#  'RENAULT/CLIO PRI 10 16VS',
#  'FORD/CARGO 1415',
#  'I/SHINERAY XY50Q PHOENIX',
#  'PEUGEOT/206 10 SENSAT',
#  'MERCEDES-BENZ/O 371 RSD',
#  'MERCEDES-BENZ/L 1218 R',
#  'FORD/CARGO 1517 E',
#  'FORD/ RANGER XLT 12A',
#  'TOYOTA/ HILUX CDSRXA4FD',
#  'SCANIA/BUSSCAR PANORAM R',
#  'FORD/ESCORT 1.8 GL',
#  'FIAT/STRADA HD WK CC E',
#  'SCANIA/ MPOLO PARADIS R',
#  'VOLKSWAGEN/GOL CITY MB',
#  'CHEVROLET/ASTRA HATCH',
#  'MERCEDES-BENZ/L1622',
#  'VOLKSWAGEN/CIFERAL CITMAX U',
#  'I/MERCEDES',
#  'FORD/F100',
#  'MITSUBISHI MOTORS/ PAJERO DAKAR',
#  'KIA/ CERATO EX3 1.6MTNB',
#  'FIAT/FIORINO WORKING',
#  'FIAT/DOBLO ELX',
#  'IVECO/ STRALIS 570S41T',
#  'MITSUBISHI MOTORS/ PAJERO GLS',
#  'VOLKSWAGEN/VOYAGE CL MB',
#  'HONDA/PCX 150',
#  'FORD/CARGO 4331 S',
#  'RENAULT/ CLIO AUT1016VH',
#  'FORD/PAMPA 1.8 L',
#  'CHEVROLET/CELTA 2P SUPER',
#  'FIAT/TIPO 1.6 MPI',
#  'CHEVROLET/CHEVROLET D20 CUSTOM S',
#  'VOLVO/FH 480 6X4T',
#  'CHEVROLET/ONIX 1.4AT LTZ',
#  'HYUNDAI/HB20 1.6A COMF',
#  'IVECO/STRALIHD 740S42TZN',
#  'VOLKSWAGEN/GOL 1.6 MI',
#  'RENAULT/ CLIO RL 1.0',
#  'VOLKSWAGEN/ VOYAGE GL',
#  'CHEVROLET/PRISMA 10MT JOYE',
#  'SCANIA/R124 GA6X4NZ 360',
#  'CHEVROLET/S10 COLINA S 4X4',
#  'VOLKSWAGEN/NOVA SAVEIRO RB MBVS',
#  'SCANIA/ T124GA4X2 360',
#  'FORD/F600',
#  'VOLKSWAGEN/9.160 DRC 4X2',
#  'MERCEDES-BENZ/O 400 RSE PL',
#  'FIAT/WEEKEND ADVENTURE',
#  'MERCEDES-BENZ/ 515CDISPRINTERM',
#  'CHEVROLET/CARAVAN',
#  'MERCEDES-BENZ/L 1418 R',
#  'VOLKSWAGEN/NOVO GOL TL MBV',
#  'FORD/FIESTA GL CLASS',
#  'CHEVROLET/S10 TORNADO D 4X4',
#  'FIAT/STILO SPORTING DUAL',
#  'FIAT/STILO SPORTING FLEX',
#  'MARCOPOLO/VOLARE V8 MO',
#  'FORD/VERSAILLES 2.0 GL',
#  'FIAT/ PALIO EL',
#  'FORD/F 1000',
#  'MERCEDES-BENZ/712 C',
#  'VOLKSWAGEN/18310 TITAN VIR 4X2',
#  'PEUGEOT/ 207 HB XS',
#  'FIAT/MAREA HLX',
#  'SCANIA/R 113 H 4X2 360',
#  'VOLKSWAGEN/MPOLO TORINO GVU',
#  'YAMAHA/XJ6 N',
#  'VOLKSWAGEN/SPACEFOX TREND GII',
#  'PEUGEOT/ 206 14PRESENFX',
#  'I/JAC J3 TURIN',
#  'SCANIA/P94GA4X2NZ 310',
#  'MERCEDES-BENZ/MPOLO PARADISO LD',
#  'RENAULT/ CLIO AUT 10H3P',
#  'FIAT/UNO ECONOMY',
#  'VOLKSWAGEN/GOL 1.6 POWER GIV',
#  'RENAULT/LOGAN PRI 1616V',
#  'MERCEDES-BENZ/L 2318',
#  'MERCEDES-BENZ/MPOLO SENIOR GVO',
#  'SCANIA/MPOLO PARADISO DD',
#  'VOLKSWAGEN/GOL CL 1.8 MI',
#  'PEUGEOT/ 307',
#  'M. BENZ / LS 1632',
#  'PEUGEOT/ 207 PASSION XR',
#  'SCANIA/R124 LA6X2NA 400',
#  'IVECO/DAILY35S14 CS',
#  'JTA/SUZUKI AN125',
#  'FIAT/TEMPRA SX',
#  'NISSAN/ SENTRA',
#  'FORD/CARGO 815 S',
#  'CHEVROLET/D20',
#  'VOLKSWAGEN/ GOLF GLX',
#  'FIAT/PALIO WEEK 6MARCHAS',
#  'IVECO/STRALIS 490S41T',
#  'VOLKSWAGEN/GOL GTS',
#  'MERCEDES-BENZ/NEOBUS THUNDER LO',
#  'HONDA/LEAD 110',
#  'FORD/ECOSPORT XL 1.6L',
#  'RENAULT/CLIO EXP 16 16VS',
#  'VOLKSWAGEN/NOVA SAVEIRO CE CROSS',
#  'VOLKSWAGEN/SAVEIRO CS ST MB',
#  'MERCEDES-BENZ/CAIO APACHES21 U',
#  'MERCEDES-BENZ/ACTROS 2546LS',
#  'VOLKSWAGEN/19.370 CLM T 4X2',
#  'MERCEDES-BENZ/LS 1934',
#  'MERCEDES-BENZ/',
#  'VOLKSWAGEN/ SPACEFOX TREND GII',
#  'CHEVROLET/CRUZE LTZ NB',
#  'FORD/ FIESTA SE HA',
#  'SCANIA/L110',
#  'FIAT/SIENA TETRAFUEL 1.4',
#  'FORD/ RANGER XLS 13P',
#  'VOLKSWAGEN/SAVEIRO CLI',
#  'TRAXX/JL50 Q2',
#  'VOLKSWAGEN/17.220',
#  'IMP/HONDA CIVIC LX',
#  'HONDA/NX 200',
#  'INTERNATIONAL/9800I 6X4',
#  'CHEVROLET/CLASSIC SUPER',
#  'FIAT/PALIO WEEK HLX FLEX',
#  'HONDA/ CBR 600RR',
#  'VOLKSWAGEN/23.310',
#  'CHEVROLET/COBALT 1.8 LT',
#  'FIAT/TORO FREEDOM AT',
#  'FORD/CARGO 4031',
#  'CHEVROLET/ CORSA SUPER',
#  'RENAULT/SCENIC RXE1.6 16',
#  'CHEVROLET/S10 ADVANTAGE S',
#  'HONDA/ CIVIC LXS',
#  'MONARK/',
#  'FORD/KA SE 1.5 SD',
#  'SCANIA/P124GA4X2NZ 360',
#  'VOLKSWAGEN/LOGUS CL',
#  'VOLKSWAGEN/ POLO CLASSIC 1.8',
#  'MERCEDES-BENZ/MPOLO VIAGGIO GVR',
#  'TOYOTA/ HILUX 2CD',
#  'VOLKSWAGEN/MPOLO VIAGGIO R',
#  'FIAT/UNO MILLE SX YOUNG',
#  'FIAT/PREMIO',
#  'CITROEN/ C4 PALLAS20G F',
#  'FIAT/MOBI LIKE',
#  'NISSAN/FRONTIER',
#  'VOLKSWAGEN/NOVO VOYAGE TL MBV',
#  'FORD/ RANGER XLS 10A',
#  'MERCEDES-BENZ/413CDI SPRINTERM',
#  'AUDI/A3 1.6',
#  'RENAULT/SANDERO EXPR 16',
#  'VOLKSWAGEN/GOL 1.0 COPA',
#  'CITROEN/ C4 PALLAS20EXA',
#  'VOLKSWAGEN/SANTANA GL 2000',
#  'FIAT/UNO ATTRACTIVE 1.0',
#  'FIAT/SIENA 1.4',
#  'MERCEDES-BENZ/OF1722M NEOBUS MG',
#  'VOLKSWAGEN/13.130',
#  'VOLKSWAGEN/GOL I PLUS',
#  'HONDA/',
#  'FIAT/BRAVO ESSENCE 1.8',
#  'FORD/DEL REY GHIA',
#  'FIAT/IDEA',
#  'PEUGEOT/ 408 ALLURE',
#  'KIA/ CERATO SX3 1.6ATNB',
#  'VOLKSWAGEN/QUANTUM CL',
#  'VOLKSWAGEN/GOL LS',
#  'HONDA/NX 350 SAHARA',
#  'VOLKSWAGEN/ GOL CL 1.8',
#  'SUNDOWN/HUNTER 125 SE',
#  'CHEVROLET/ COBALT LT',
#  'FORD/DEL REY GL',
#  'VOLKSWAGEN/17.250 CNC',
#  'VOLKSWAGEN/PARATI LS',
#  'HONDA/ML 125',
#  'MERCEDES-BENZ/MPOLO SEN MIDI ON',
#  'MITSUBISHI MOTORS/L200 TRITON HPE D',
#  'MERCEDES-BENZ/MPOLO PARADISO DD',
#  'CHEVROLET/S10 DE LUXE 2.8 D 4X4',
#  'FORD/ ESCORT 1.8I GL',
#  'HYUNDAI/ VELOSTER',
#  'VOLKSWAGEN/UP MOVE MA',
#  'YAMAHA/T115 CRYPTON K',
#  'VOLKSWAGEN/16.170 BT',
#  'VOLKSWAGEN/13.190 CRM 4X2',
#  'CITROEN/C3 AIRCROSS GLXM',
#  'VOLKSWAGEN/16.180 CO',
#  'HONDA/CB500',
#  'MARCOPOLO/VOLARE DW9 ON',
#  'VOLKSWAGEN/LOGUS GL',
#  'CHEVROLET/ CORSA SEDAN',
#  'SCANIA/G 470 A6X4',
#  'VOLKSWAGEN/7.110',
#  'JTA/SUZUKI GSXR750',
#  'FORD/CARGO 1418',
#  'HYUNDAI/TUCSON GLB',
#  'VOLKSWAGEN/COMIL SVELTO U',
#  'HONDA/XLR 125 ES',
#  'FORD/F250 XLT W21',
#  'FORD/ RANGER XLT',
#  'CITROEN/ C4 PALLAS20EAF',
#  'VOLKSWAGEN/LOGUS CLI 1.8',
#  'YAMAHA/T115 CRYPTON ED',
#  'FORD/F1000S',
#  'FORD/CARGO 2428 CN',
#  'RENAULT/ SYMBOL EXPR 16',
#  'MERCEDES-BENZ/ATEGO 1719',
#  'FIAT/DOBLO CARGO 1.4',
#  'MERCEDES-BENZ/1418',
#  'IMP/VOLVO',
#  'MERCEDES-BENZ/BUSSCAR URBPLUS U',
#  'VOLVO/MPOLO PARADISO DDR',
#  'TOYOTA/ETIOS SD X',
#  'MERCEDES-BENZ/ATEGO 1718',
#  'YAMAHA/XTZ 250X',
#  'MERCEDES-BENZ/914 C',
#  'NISSAN/FRONTIER XE 25 X4',
#  'CHEVROLET/S10 DLX 2.8 D',
#  'VOLVO/FH12 420 6X2T',
#  'VOLKSWAGEN/PARATI 16V TURBO',
#  'FIAT/PUNTO HLX 1.8',
#  'CHEVROLET/OPALA COMODORO',
#  'VOLKSWAGEN/PARATI S',
#  'FIAT/PREMIO S',
#  'VOLKSWAGEN/14.220',
#  'VOLKSWAGEN/GOL PATRULHEIRO 1.6',
#  'SCANIA/ BUSSCAR JB R',
#  'FIAT/PALIO WEEKEND EX',
#  'SCANIA/T113 H',
#  'VOLKSWAGEN/GOL HIGHWAY',
#  'VOLVO/N10 INTERCOOLER II',
#  'CHEVROLET/ASTRA HATCH 5P GSI',
#  'MERCEDES-BENZ/ SPRINTER 313',
#  'HONDA/CG 125 FAN ESD',
#  'FORD/BELINA',
#  'FIAT/PUNTO SPORTING 1.8',
#  'FIAT/PUNTO',
#  'PEUGEOT/206 SW16 ESCA FX',
#  'VOLKSWAGEN/PARATI CL 1.8 MI',
#  'YAMAHA/ YZF R1',
#  'MERCEDES-BENZ/1420',
#  'NISSAN/ SENTRA 20S FLEX',
#  'FIAT/FIORINO TREKKING',
#  'FORD/BELINA II',
#  'FORD/CARGO 815 N',
#  'IMP/MBENZ 310D SPRINTERF',
#  'MERCEDES-BENZ/ATEGO 1518',
#  'FIAT/UNO MILLE ELECTRONI',
#  'HYUNDAI/HB20 1.6A PREM',
#  'VOLKSWAGEN/26.260 E',
#  'CHEVROLET/ASTRA SUNNY',
#  'FIAT/FIORINO 1.0',
#  'FIAT/147',
#  'VOLKSWAGEN/GOL 1.0 POWER',
#  'FORD/ ESCORT GLX 16VH',
#  'SCANIA/ G 420 LA6X4HNA',
#  'VOLKSWAGEN/NOVA SAVEIRO CE',
#  'VOLKSWAGEN/ JETTA 2.0T',
#  'FIAT/STILO FLEX DUALOGIC',
#  'MERCEDES-BENZ/MASCA GRANMIDI O',
#  'CITROEN/C3 XTR 14 FLEX',
#  'FIAT/PUNTO 1.4',
#  'MERCEDES-BENZ/ LF 1113 B',
#  'FORD/ ESCORT GLX 16VF',
#  'FIAT/PALIO 1.8 R FLEX',
#  'MERCEDES-BENZ/ 1318',
#  'CHEVROLET/ SILVERADO',
#  'CITROEN/XSARA PICASSOGXS',
#  'CHEVROLET/SPIN 1.8L AT LT',
#  'VOLKSWAGEN/24.250E WORKER 6X2',
#  'VOLKSWAGEN/FOX 1.0 ROUTE',
#  'I/CHERY QQ3 1.1',
#  'CHEVROLET/BLAZER EXECUTIVE',
#  'FORD/ ESCORT GL 16V',
#  'CHEVROLET/MONZA CLASSIC SL/E',
#  'CHEVROLET/CHEVETTE MARAJO',
#  'RENAULT/MEGANESD EXPR 16',
#  'FIAT/DUCATO M BUS RONTAN',
#  'FIAT/DUCATO MULTI',
#  'CHEVROLET/CHEVETTE SE',
#  'MERCEDES-BENZ/ATRON 1319',
#  'MERCEDES-BENZ/AXOR 2044 S',
#  'MERCEDES-BENZ/1938',
#  'FIAT/IDEA ADVENTURE DUAL',
#  'SCANIA/K 113 CL',
#  'NISSAN/ SENTRA S',
#  'CHEVROLET/ CAPTIVA SPORT 2.4',
#  'VOLKSWAGEN/LOGUS',
#  'FORD/DEL REY BELINA L',
#  'FIAT/ PALIO ELX',
#  'HONDA/C100 BIZ MAIS',
#  'FIAT/LINEA ABSOLUTE DUAL',
#  'VOLVO/FH 460 4X2T',
#  'MITSUBISHI MOTORS/L200 TRITON SPT GL',
#  'KIA/ SPORTAGE LX 2.0 G2',
#  'VOLKSWAGEN/SAVEIRO 1.6 SURF',
#  'FORD/PAMPA GL',
#  'NISSAN/ MARCH 10S FLEX',
#  'SCANIA/R124 LA6X2NA 360',
#  'FORD/F250 XLT F22',
#  'VOLKSWAGEN/LOGUS GLI 1.8',
#  'CHEVROLET/CHEVETTE JUNIOR',
#  'RENAULT/ SYMBOL EX1616V',
#  'MERCEDES-BENZ/ 312D SPRINTER F',
#  'CITROEN/XSARA PICASSO',
#  'HYUNDAI/IX35 B',
#  'RENAULT/KWID ZEN 10MT',
#  'NISSAN/FRONTIER 4X2 SE',
#  'MERCEDES-BENZ/ATEGO 2430',
#  'JTA/SUZUKI GSXR1000',
#  'VOLVO/B12 400 6X2',
#  'FORD/F250 XLT F21',
#  'CHEVROLET/S10 2.8 S',
#  'CHEVROLET/KADETT IPANEMA SL EFI',
#  'SCANIA/G 400 A6X2',
#  'VOLKSWAGEN/SANTANA GLS 2000 I',
#  'NISSAN/ TIIDA 18SL FLEX',
#  'CHEVROLET/ CLASSIC',
#  'VOLKSWAGEN/GOL 16V TURBO',
#  'FORD/CARGO 1422',
#  'FORD/VERSAILLES 1.8 I GL',
#  'MERCEDES-BENZ/1214',
#  'NISSAN/ VERSA 16SV FLEX',
#  'CHEVROLET/PRISMA 1.4AT LT',
#  'VOLKSWAGEN/GOL 1.0L MC4',
#  'FIAT/DUCATO COMBINATO',
#  'RENAULT/ MEGANE RT 1.6',
#  'VOLKSWAGEN/ SPACEFOX SPORTLINE',
#  'NISSAN/ SENTRA 20 FLEX',
#  'RENAULT/SCENIC PRI 2016V',
#  'MERCEDES-BENZ/O 371 RSE',
#  'VOLKSWAGEN/25.320 CLC T 6X2',
#  'PEUGEOT/206 14 FELINE',
#  'MERCEDES-BENZ/MPOLO SENIOR ON',
#  'VOLKSWAGEN/ SPACEFOX ROUTE',
#  'JTA/SUZUKI EN125 YES SE',
#  'SCANIA/T 112 H 4X2',
#  'CHEVROLET/ CORSA HATCH',
#  'VOLVO/VM 260 4X2R',
#  'MAN/TGX 28.440 6X2 T',
#  'CITROEN/C3 EXCL 16 FLEX',
#  'MERCEDES-BENZ/ATEGO 2429',
#  'RENAULT/SCENIC PRI 1616V',
#  'VOLKSWAGEN/ GOLF GLX 2.0 MI',
#  'FORD/F12000 L',
#  'NISSAN/ TIIDA SEDAN 18F',
#  'FORD/CARGO 1617',
#  'HYUNDAI/ SANTA FE V6',
#  'RENAULT/DUSTER 16 E 4X2',
#  'FIAT/UNO S 1.5',
#  'VOLKSWAGEN/QUANTUM CL 1800 I',
#  'MERCEDES-BENZ/LS 1929',
#  'HYUNDAI/ SANTA FE 3.5',
#  'FORD/F250 XLT W20',
#  'VOLKSWAGEN/SANTANA CD',
#  'FORD/ MONDEO CLX FD',
#  'YAMAHA/CRYPTON T105E',
#  'FORD/ FOCUS GHIA 2.0LHA',
#  'TOYOTA/ LAND CRUISER PR',
#  'RENAULT/SANDERO STEP 16',
#  'VOLKSWAGEN/ TIGUAN 2.0 TSI',
#  'FORD/ FOCUS FC FLEX',
#  'HONDA/XRE 190',
#  'CHEVROLET/ OMEGA CD',
#  'FIAT/UNO ATTRACTIVE 1.4',
#  'RENAULT/MASTER MBUS L3H2',
#  'FIAT/DUCATO MULT JAEDI T',
#  'KAWASAKI/NINJA 250R',
#  'CHEVROLET/ASTRA HATCH 5P',
#  'MERCEDES-BENZ/2423 K',
#  'SCANIA/T142 H 4X2 S',
#  'VOLKSWAGEN/MPOLO VIALE U',
#  'I/CHEV TRACKER LTZ AT',
#  'HONDA/ CIVIC LX',
#  'VOLKSWAGEN/GOL SERIE OURO',
#  'YAMAHA/FAZER YS250 LE',
#  'IMP/VOLVO FH12 420 4X2',
#  'IVECO/ TECTOR 240E25',
#  'VOLKSWAGEN/17230EOD NEOBUS MEGA',
#  'TOYOTA/ RAV4',
#  'VOLKSWAGEN/COMIL PIA O',
#  'FORD/CARGO 4432 E',
#  'ITAPEMIRIM/SBVM',
#  'MERCEDES-BENZ/M.BENZ L 1313',
#  'CHEVROLET/S10 RODEIO D',
#  'TOYOTA/ HILUX SWSRXA4FD',
#  'FORD/FIESTA CLX',
#  'MERCEDES-BENZ/608',
#  'SCANIA/R 440 A4X2',
#  'MERCEDES-BENZ/AXOR 2535 S',
#  'PEUGEOT/ 308 ALLURE',
#  'FIAT/TORO VOLCANO AT D4',
#  'MERCEDES-BENZ/ ACTROS2646LS6X4',
#  'TOYOTA/ HILUX CD4X2',
#  'MERCEDES-BENZ/L 708 E',
#  'MERCEDES-BENZ/OF 1113',
#  'CHEVROLET/KADETT IPANEMA',
#  'NISSAN/ FRONTIER 4X4 SE',
#  'HONDA/NXR150 BROS MIX KS',
#  'VOLKSWAGEN/14.210',
#  'FORD/VERONA 1.8 LX',
#  'SCANIA/T 113 H 4X2 320',
#  'FIAT/SIENA ESSENC 1.6 DL',
#  'PEUGEOT/206',
#  'FIAT/ PALIO WEEKEND 1.4',
#  'FORD/ RANGER XL 13F',
#  'MERCEDES-BENZ/OF1418 NEOBUS SPEC',
#  'VOLKSWAGEN/KOMBI PICK UP',
#  'FORD/CARGO 1618',
#  'TROLLER/T4 TDI 3.0',
#  'RENAULT/LOGAN EXP 16 HP',
#  'VOLKSWAGEN/19320CNCTT SAOJOAO CP',
#  'CITROEN/ C4',
#  'HONDA/SHADOW 750',
#  'FORD/ESCORT 1.8 L',
#  'SCANIA/ R113 H-360 4X2',
#  'CHEVROLET/KADETT SL/E EFI',
#  'FORD/F12000 160',
#  'CITROEN/XSARA PICASSOEXA',
#  'CHEVROLET/S10 DE LUXE 2.5 D 4X4',
#  'VOLKSWAGEN/GOL SERIE OURO 2000',
#  'YAMAHA/XT 600 E',
#  'MERCEDES-BENZ/LS 1932',
#  'FORD/KA 1.6 FLEX',
#  'FIAT/UNO FLEX',
#  'VOLKSWAGEN/GOL TL MB',
#  'FORD/FIESTA HA 1.5L SE',
#  'FORD/KA SE 1.0 HA C',
#  'FORD F250 XLTG',
#  'I/SSANGYONG KYRONM200XDI',
#  'VOLKSWAGEN/SANTANA CS',
#  'CITROEN/XSARA PICASSOEXS',
#  'SCANIA/T 112 H',
#  'CHEVROLET/S10 2.4 S',
#  'VOLKSWAGEN/COMIL VERSATILE I',
#  'VOLKSWAGEN/25.420 CTC 6X2',
#  'FORD/CARGO 1317F',
#  'FIAT/ PALIO ED',
#  'PEUGEOT/206 SW 14PRESENC',
#  'VOLVO/NL10 310 4X2',
#  'CHEVROLET/D20 CONQUEST',
#  'VOLKSWAGEN/LOGUS CLI',
#  'CHEVROLET/S10 2.5 D 4X4',
#  'VOLKSWAGEN/GOL ROLLING STONES',
#  'FORD/CARGO 1317',
#  'RENAULT/MASTER MINIBUS16',
#  'VOLKSWAGEN/SAVEIRO 1.6 TITAN',
#  'MERCEDES-BENZ/MPOLO PARADISO DDR',
#  'FIAT/PALIO 1.0 FLEX',
#  'VOLKSWAGEN/SANTANA CL 1800',
#  'SCANIA/T 112 HS 4X2',
#  'RENAULT/MEGANESD DYN 20A',
#  'FORD/ RANGER LTD CD4 32',
#  'I/VOLVO FM12 380 4X2T',
#  'FORD/11000',
#  'FORD/ ESCORT GL 1.6 F',
#  'CITROEN/C3 EXC 16 A FLEX',
#  'FIAT/ARGO DRIVE 1.0',
#  'VOLKSWAGEN/12.170 BT',
#  'RENAULT/',
#  'TOYOTA/COROLLA XLI',
#  'VOLKSWAGEN/VOYAGE CL 1.8',
#  'FORD/ F4000',
#  'FORD/ECOSPORT SE 1.6',
#  'TOYOTA/COROLLA ALTISFLEX',
#  'VOLKSWAGEN/40.300',
#  'NISSAN/FRONTIER SVATK4X4',
#  'NISSAN/XTERRA 2.8 SE',
#  'TOYOTA/ HILUX 4CDL SR',
#  'VOLKSWAGEN/35.300',
#  'SCANIA/T 112 HW 4X2',
#  'CHEVROLET/KADETT GSI MPFI',
#  'KIA/ PICANTO EX3 1.0L',
#  'VOLKSWAGEN/POINTER CLI 1.8',
#  'KIA/ SOUL EX 1.6L',
#  'FIAT/UNO MILLE BRIO',
#  'M.BENZ',
#  'CHEVROLET/ D20 CUSTOM S',
#  'CHEVROLET/S10 2.2 D',
#  'FORD/VERSAILLES GL',
#  'FORD/FIESTA HA 1.6L SE',
#  'MITSUBISHI MOTORS/ LANCER 2.0',
#  'KASINSKI/COMET 250R',
#  'MERCEDES-BENZ/L 1218 EL',
#  'HYUNDAI/ ELANTRA GLS',
#  'FIAT/UNO S IE',
#  'VOLKSWAGEN/GOL FUN',
#  'VOLKSWAGEN/ SPACEFOX SPORT.GII',
#  'FORD/ TRANSIT 350L TA',
#  'RENAULT/CLIO RN 1.6 16V',
#  'CHEVROLET/VECTRA CHALLENGE',
#  'VOLKSWAGEN/24.220',
#  'MITSUBISHI MOTORS/ ASX 2.0',
#  'FORD/ RANGER XLT CD4 32',
#  'MERCEDES-BENZ/AXOR 28316X4',
#  'HONDA/ 125',
#  'RENAULT/LOGAN DYNA 16 M',
#  'VOLKSWAGEN/VOYAGE S',
#  'PEUGEOT/207HB XS',
#  'IVECO/ECTECTOR 230E24N',
#  'VOLKSWAGEN/SAVEIRO CD CROSS MA',
#  'HYUNDAI/ VERACRUZ 3.8V6',
#  'VOLKSWAGEN/ AMAROK CD 4X4',
#  'IVECO/TECTOR 240E25S',
#  'FORD/ RANGER XL 13D',
#  'MERCEDES-BENZ/ 313 CDI FFBM 28',
#  'VOLKSWAGEN/PARATI CLI',
#  'MERCEDES-BENZ/MPOLO PARAD GVLDR',
#  'FORD/PAMPA 1.8 GL',
#  'CHEVROLET/CRUZE LTZ HB',
#  'CHEVROLET/ASTRA SPORT',
#  'KIA/ SORENTO EX2 2.4G25',
#  'RENAULT/SANDERO PRI1616V',
#  'SUZUKI/ G.VITARA 4WD 5P',
#  'MITSUBISHI MOTORS/ L200 SPORT 4X4',
#  'CHEVROLET/MONZA CLASSIC',
#  'VOLKSWAGEN/PARATI 1.8 TOUR',
#  'FORD/ ESCORT GL',
#  'VOLKSWAGEN/ BEETLE',
#  'MERCEDES-BENZ/ACTROS 2651S6X4',
#  'FORD/ RANGER XLS CD2 25',
#  'VOLKSWAGEN/8.150E-CUMMINS',
#  'FIAT/ SIENA 6 MARCHAS',
#  'FIAT/PALIO WEEKEND 16V',
#  'FORD/ RANGER XLS 13F',
#  'CHEVROLET/S10 LS DS4',
#  'NISSAN/FRONTIER SL 4X4',
#  'MERCEDES-BENZ/LP 321',
#  'VOLVO/B10M 4X2',
#  'CITROEN/C3 AIRCROSS EXCM',
#  'VOLKSWAGEN/ FOX 1.6 PRIME GII',
#  'HONDA/ FIT',
#  'MERCEDES-BENZ/MPOLO PARAD GVDDR',
#  'TOYOTA/BAND MAX',
#  'TROLLER/T4 TDI',
#  'MARCOPOLO/VOLARE A8 ON',
#  'FIAT/ PALIO EDX',
#  'FIAT/ELBA WEEKEND',
#  'HONDA/C100 DREAM',
#  'FIAT/PALIO HLX FLEX',
#  'RENAULT/MAST MARTICAR 19',
#  'MERCEDES-BENZ/L 2014',
#  'RENAULT/SANDERO SW1616VA',
#  'FORD/ RANGER XL 12D',
#  'VOLKSWAGEN/ PASSAT',
#  'I/CHERY TIGGO 2.0',
#  'FORD/ESCORT 1.8I GL',
#  'NISSAN/FRONTIER XE 4X4',
#  'FORD/B 1618',
#  'FORD/C2428 PMERECHIM 8X2',
#  'RENAULT/M REVESCAP L3H2',
#  'FORD/CARGO 1717',
#  'TOYOTA/ETIOS HB XLS',
#  'I/VOLVO FH 520 6X4T',
#  'TOYOTA/ COROLLA XLI',
#  'VOLVO/NL10 320 4X2T EDC',
#  'CHEVROLET/SILVERADO D20',
#  'FIAT/STRADA TREK CD 1.6',
#  'TOYOTA/ HILUX 2CDL SRV',
#  'FORD/ ESCORT GL 1.6 H',
#  'FIAT/PREMIO CS 1.5',
#  'TOYOTA/ HILUX CS4X4CHAS',
#  'FORD/ RANGER 13P',
#  'HONDA/VT600C SHADOW',
#  'JEEP/RENEGADE LNGTD AT',
#  'FIAT/DUCATO MC RONTANAMB',
#  'CHEVROLET/TRAILBLAZER LT D4A',
#  'VOLKSWAGEN/GOL PLUS',
#  'MERCEDES-BENZ/L 1517',
#  'MERCEDES-BENZ/1214 C',
#  'CHEVROLET/COBALT 1.4 LS',
#  'VOLKSWAGEN/GOL 1.6 CITY',
#  'FIAT/ UNO CSL 1.6',
#  'VOLKSWAGEN/SAVEIRO GL',
#  'HONDA/CIVIC EXR',
#  'RENAULT/SCENIC RT 2.0',
#  'MERCEDES-BENZ/ 311CDI STREET F',
#  'FIAT/IDEA ESSENCE 1.6',
#  'PEUGEOT/207PASSION XS',
#  'RENAULT/LOGAN PRI 16',
#  'CHEVROLET/ASTRA HATCH 3P',
#  'TOYOTA/BAND. BJ55LP BL3',
#  'FORD/ TRANSIT 350L BUS',
#  'VOLKS/BUSSCAR URBANUSS U',
#  'PEUGEOT/206 SW16 FELI FX',
#  'KIA/ SOUL EX 1.6 FF MT',
#  'VOLKSWAGEN/PARATI GLI 1.8',
#  'FORD/FIESTA CLX 16V',
#  'VOLKSWAGEN/APOLLO GLS',
#  'MITSUBISHI MOTORS/ OUTLANDER 2.0',
#  'RENAULT/CLIO PRI 10 16VH',
#  'VOLKSWAGEN/14.170 BT',
#  'CHEVROLET/MERIVA EXPRESSION',
#  'VOLKSWAGEN/11.130',
#  'VOLVO/N12',
#  'RENAULT/ CLIO AUT1016VS',
#  'VOLKSWAGEN/ GOLF 2.0',
#  'PEUGEOT/BOXER M33OM HDI',
#  'CHEVROLET/CHEVROLET D20 CUSTOM L',
#  'VOLKSWAGEN/VOYAGE GL 1.8',
#  'IMP/MBENZ 310D SPRINTERC',
#  'FIAT/DOBLO ELX 1.4',
#  'AGRALE/9200 TCA',
#  'I/SSANGYONG ACTYON SP4X4',
#  'CHEVROLET/ SILVERADO T',
#  'MERCEDES-BENZ/1418 R',
#  'YAMAHA/YBR150 FACTOR E',
#  'VOLKSWAGEN/PARATI CLUB',
#  'FIAT/BRAVA ELX',
#  'VOLVO/FH 420 6X2T',
#  'VOLVO/FH 520 6X2T',
#  'FORD/CARGO 1119',
#  'I/CHERY FACE 1.3',
#  'HONDA/HR-V EX CVT',
#  'CITROEN/ C4 PIC GLXA 5L',
#  'RENAULT/MASTER CC 2.5DCI',
#  'VOLKSWAGEN/17.210 MOTOR MWM',
#  'VOLKSWAGEN/NOVO GOL 1.0 TRACK',
#  'CHEVROLET/ASTRA SEDAN ELITE',
#  'VOLKSWAGEN/17.250 CLC',
#  'FORD/ RANGER XL CD4 22',
#  'VOLKSWAGEN/SANTANA GL',
#  'TOYOTA/ HILUX SW4 4X2SR',
#  'HONDA/CG 125 FAN JOB KS',
#  'IVECO/TECTOR 240E28',
#  'VOLKSWAGEN/PARATI 1.8 TRACKFIELD',
#  'HONDA/FIT DX FLEX',
#  'CHEVROLET/S10 LT DD2',
#  'CHEVROLET/KADETT GS',
#  'VOLKSWAGEN/QUANTUM 2000 MI',
#  'CHEVROLET/KADETT IPANEMA SL',
#  'VOLKSWAGEN/13.150',
#  'FORD/ CARGO 1830',
#  'FIAT/TEMPRA HLX 16V',
#  'MERCEDES-BENZ/L 1118',
#  'VOLKS/BUSSCAR EL BUSS R',
#  'HONDA/HR-V EXL CVT',
#  'FIAT/DOBLO 1.4',
#  'SCANIA/K 113 TL',
#  'TOYOTA/ COROLLA GLI',
#  'FIAT/FIAT UNO S',
#  'MITSUBISHI MOTORS/ PAJERO SP4X4 HPE D',
#  'HONDA/CB 500F',
#  'CHEVROLET/CHEVROLET D60',
#  'KIA/ SPORTAGE LX2 OFFG4',
#  'RENAULT/ CLIO EXP1016VS',
#  'IVECO/STRALISHD 450S38T',
#  'RENAULT/CLIO RT 1.6 16V',
#  'FORD/CARGO 814',
#  'RENAULT/MASTER13M3 25DCI',
#  'CHEVROLET/CARAVAN COMODORO',
#  'PEUGEOT/208 ALLURE',
#  'IMP/M.BENZ 310D SPRINTERM',
#  'VOLVO/FH 500 6X2T',
#  'IVECO/ STRALIS 740S46TZ',
#  'FIAT/UNO FIORINO 1.5',
#  'VOLKS/BUSSCAR URBPLUSS U',
#  'I/CHEV SONIC LTZ NB AT',
#  'MERCEDES-BENZ/AXOR 2640S6X4',
#  'SCANIA/K112 33 S',
#  'FORD/CARGO 2423',
#  'MARCOPOLO/VOLARE A5 MO',
#  'FORD/VERSAILLES 2.0 I GL',
#  'VOLKSWAGEN/ GOLF GTI',
#  'MERCEDES-BENZ/A 190',
#  'PEUGEOT/206 16 FELINE FX',
#  'FORD/ RANGER 13D',
#  'VOLKSWAGEN/NOVO FOX CL MB',
#  'IVECO/ECCURSOR 450E32T',
#  'TOYOTA/',
#  'FORD/KA SE 1.5 SD B',
#  'HONDA/BIZ 100 KS',
#  'DAFRA/SUPER 100',
#  'VOLVO/B58 4X2',
#  'VOLKSWAGEN/FOX ROCK IN RIO',
#  'HYUNDAI/ SONATA GLS',
#  'MERCEDES-BENZ/AXOR 2536 S',
#  'CHEVROLET/ CAPTIVA SPORT AWD',
#  'NISSAN/FRONTIER S 4X4',
#  'AGRALE/8500 TCA',
#  'PEUGEOT/BOXER M330M 23S',
#  'KIA/ K2500 LD',
#  'SCANIA/ R124GA6X4 360',
#  'VOLKSWAGEN/14.140',
#  'VOLKSWAGEN/ GOLF GL 1.8 MI',
#  'FIAT/STRADA HD WK CD E',
#  'VOLKSWAGEN/PARATI GL 1.8 MI',
#  'SCANIA/T112 HW',
#  'CHEVROLET/CHEVETTE SL/E',
#  'MERCEDES-BENZ/313CDI SPRINTERC',
#  'DAFRA/RIVA 150',
#  'MERCEDES-BENZ/AXOR 3344S6X4',
#  'SCANIA/G 440 A6X4',
#  'NISSAN/FRONTIER 4X2 XE',
#  'VOLVO/BUSSCAR JUM BUSS R',
#  'RENAULT/MASTER11M3 25DCI',
#  'CHEVROLET/BLAZER DLX 2.8 4X4',
#  'DAF/XF105 FTS 460A',
#  'SCANIA/R114 GA4X2NZ 320',
#  'CHEVROLET/CHEVETTE SL 1.6',
#  'MERCEDES-BENZ/AXOR 2533',
#  'FORD/FIESTA HA 1.6L SE A',
#  'RENAULT/CLIO EXP 16 16VH',
#  'RENAULT/CLIO PRI 16 16VH',
#  'MERCEDES-BENZ/311CDI SPRINTERM',
#  'CHEVROLET/CHEVROLET 60',
#  'HYUNDAI/HB20 1.0M UNIQUE',
#  'CHEVROLET/**********',
#  'CHEVROLET/ CORSA MILENIUM',
#  'VOLKSWAGEN/17.300',
#  'VOLKSWAGEN/NOVO VOYAGE 1.6 COMF.',
#  'I/SINOTRUK HOWO 6X2 380',
#  'RENAULT/ CLIO 1.2',
#  'I/SHINERAY XY 150 5',
#  'FORD/ESCORT GHIA',
#  'VOLKSWAGEN/NOVO VOYAGE 1.0 CITY',
#  'CHEVROLET/C20 CUSTOM S',
#  'FIAT/UNO 1.5 R',
#  'MERCEDES-BENZ/OF 1313',
#  'RENAULT/DUSTER 20 D 4X4',
#  'TOYOTA/ HILUX 4CDK SR',
#  'YAMAHA/FZ25 FAZER',
#  'CHEVROLET/OMEGA SUPREMA GLS',
#  'FIAT/FIORINO AMBULANCIA',
#  'FORD/F1000 TURBO',
#  'PEUGEOT/ 206 14 SENSAT',
#  'FIAT/ TEMPRA SW SLX',
#  'VOLVO/COMIL CAMPIONE R',
#  'SCANIA/T112 MA 4X2',
#  'IVECO/DAILY 70C16HDCS',
#  'VOLVO/NH12 420 4X2T',
#  'FORD/BELINA II L',
#  'VOLKSWAGEN/CAIO APACHES21 U',
#  'RENAULT/MASTER FUR L3H2',
#  'VOLKSWAGEN/MPOLO SENIOR GVO',
#  'FORD/ EDGE V6',
#  'RENAULT/ CLIO PRI1616VS',
#  'VOLKSWAGEN/GOLF GTI',
#  'FIAT/DOBLO RONTAN AMB2',
#  'SCANIA/R 400 A6X2',
#  'MITSUBISHI MOTORS/ PAJERO GLS-B',
#  'DAFRA/NEXT 250',
#  'RENAULT/MEGANEGT DYN 20A',
#  'VOLKSWAGEN/13.180 E',
#  'IVECO/ CURSOR 450E33T',
#  'RENAULT/MASTERAMB RONTAN',
#  'CHEVROLET/ SILVERADO DLX T',
#  'TOYOTA/ETIOS HB XS',
#  'CHEVROLET/ASTRA HB 4P COMFORT',
#  'SCANIA/R112 H 4X2',
#  'VOLKSWAGEN/QUANTUM GL 2000 I',
#  'CHEVROLET/ S10 4.5 E',
#  'FORD/ESCORT 1.8 XR3',
#  'VOLKSWAGEN/BMB 24.250 CNC 8X2',
#  'MERCEDES-BENZ/LK 1113',
#  'IVECO/ STRALIS 570S46T',
#  'MERCEDES-BENZ/AXOR 2036 S',
#  'VOLKSWAGEN/PARATI 16V PLUS',
#  'FORD/DEL REY GLX',
#  'CHEVROLET/S10 RODEIO 2.8 D 4X4',
#  'HYUNDAI/ I30',
#  'IVECO/STRALISHD 490S38T',
#  'FORD/FIESTA SUPERCHARGER',
#  'RENAULT/CLIO AUT 16 16VH',
#  'TOYOTA/ HILUX 4CD DLX',
#  'VOLKSWAGEN/13.190',
#  'ITAPEMIRIM/2-12910-212',
#  'IMP/RENAULT CLIO RT',
#  'VOLKSWAGEN/MPOLO SENIOR ON',
#  'FORD/CORCEL LUXO',
#  'PEUGEOT/ 207 5P',
#  'VOLKSWAGEN/GOL 1.6L MB5',
#  'YAMAHA/XTZ 125XE',
#  'FIAT/ SIENA HL',
#  'CHEVROLET/MONTANA ENGESIG FURG',
#  'IVECO/STRALIS 600S40T',
#  'IVECO/STRALIS 490S38T',
#  'VOLKSWAGEN/SAVEIRO GL 1.8',
#  'FORD/CARGO1717 E',
#  'FIAT/ FREEMONT PRECISIO',
#  'JTA/SUZUKI GSX 1300 R',
#  'VOLKSWAGEN/ POLO CLAS. 1.6 MI',
#  'TECNOBUS/BUSSCAR VBUSS R',
#  'FIAT/WEEKEND TREKKING',
#  'VOLKSWAGEN/FOX 1.6 ROUTE',
#  'IVECO/ STRALIS 490S38T',
#  'MERCEDES-BENZ/AXOR 1933 S BIASI',
#  'FORD/VERSAILLES 2.0 GHIA',
#  'CHEVROLET/ASTRA HB 4P SS',
#  'VOLKSWAGEN/GOL CL MB',
#  'CHEVROLET/OPALA COMODORO SL/E',
#  'FIAT/MAREA WEEKEND ELX',
#  'VOLKSWAGEN/SANTANA 2000 MI EVID.',
#  'MERCEDES-BENZ/LAK 1314',
#  'FORD/ESCORT GL 16V F',
#  'FORD/F1000 HSD XL',
#  'HYUNDAI/HB20S 1.6M 1.6M',
#  'PEUGEOT/207PASSION XS A',
#  'MERCEDES-BENZ/AXOR 2640 S',
#  'NISSAN/GRAND LIVINA 18SL',
#  'I/SHINERAY XY 150 GY',
#  'VOLKSWAGEN/GOL BX',
#  'IMP/ASIA TOPIC',
#  'CHEVROLET/S10 2.4 D',
#  'MITSUBISHI MOTORS/ PAJERO SP. 4X4 GLS',
#  'FIAT/UNO 1.6 R',
#  'KIA/ SPORTAGE EX2 OFFG4',
#  'SUNDOWN/HUNTER 100',
#  'VOLKSWAGEN/GOL COPA',
#  'IVECO/FIAT P. 450E37T',
#  'FORD/ RANGER',
#  'I/DODGE RAM 2500',
#  'CHEVROLET/ D20',
#  'NISSAN/ MARCH 16S FLEX',
#  'MERCEDES-BENZ/LS 2638',
#  'IMP/M.BENZ',
#  'NISSAN/ TIIDA 18S FLEX',
#  'FORD/KA SE 1.0 SD B',
#  'VOLKSWAGEN/PARATI GLS',
#  'IMP/KIA BESTA 12P GS',
#  'MITSUBISHI MOTORS/L200 TRITON GLX D',
#  'TOYOTA/COROLLA XRS FLEX',
#  'SUZUKI/ G.VITARA 2WD 5P',
#  'CHEVROLET/MONZA 650',
#  'IMP/VOLVO FH12 420 6X4',
#  'TOYOTA/ COROLLA LE',
#  'MERCEDES-BENZ/COMIL PIA O',
#  'VOLKSWAGEN/QUANTUM GLS',
#  'FIAT/UNO MILLE ELETRONIC',
#  'VOLKSWAGEN/GOL 1.6 COPA',
#  'PEUGEOT/ 206 10 SENSAT',
#  'MERCEDES-BENZ/LO 814',
#  'MERCEDES-BENZ/ 312D SPRINTER C',
#  'VOLVO/MPOLO VIAGGIO R',
#  'MERCEDES-BENZ/ATEGO 1315',
#  'PEUGEOT/206 14 FELINE FX',
#  'FIAT/ELBA',
#  'JEEP/RENEGADE SPORT AT',
#  'FORD/ESCORT GL 16V H',
#  'VOLVO/FH12 380 4X2 R',
#  'FIAT/STRADA LX 16V',
#  'MERCEDES-BENZ/ACTROS 2646LS6X4',
#  'TOYOTA/ HILUX SW4 4X4SR',
#  'CITROEN/ XSARA GLX 1.6I',
#  'HYUNDAI/HB20S 1.0M 1.0M',
#  'MERCEDES-BENZ/LK 1618',
#  'VOLKSWAGEN/12.140 T',
#  'FIAT/BRAVO SPORTING 1.8',
#  'I/BASHAN JONNY HYPE 50',
#  'FIAT/PREMIO CS 1.3',
#  'YAMAHA/DRAG STAR XVS 650',
#  'CHEVROLET/MONZA CLASS EFI',
#  'VOLKSWAGEN/VOYAGE CITY MB',
#  'RENAULT/MASTER ALTECHAMB',
#  'MERCEDES-BENZ/1620 TOPLINE',
#  'FORD/CARGO 1319',
#  'MERCEDES-BENZ/AXOR 2041 S',
#  'PEUGEOT/ 307 20S A FELI',
#  'MITSUBISHI MOTORS/ OUTLANDER 3.0 V6',
#  'VOLKSWAGEN/NOVO GOL 1.6 POWER',
#  'MERCEDES-BENZ/MPOLO TORINO A',
#  'SCANIA/R 470 A6X4',
#  'RENAULT/MEGANESD DYN 20',
#  'FORD/ FUSION V6',
#  'YAMAHA/YBR125 FACTOR E',
#  'VOLVO/BUSSCAR J BU 400 R',
#  'JTA/SUZUKI DL1000',
#  'VOLKSWAGEN/9150 NEOBUS THUNDER',
#  'VOLKSWAGEN/GOL 1.6 GIV',
#  'IVECO/STRALIHD 570S42TN1',
#  'HONDA/NX 150',
#  'VOLKSWAGEN/ SPACECROSS GII',
#  'FORD/COURIER CLX',
#  'PEUGEOT/208 ACTIVE',
#  'FIAT/PALIO WEEKEND SPORT',
#  'FIAT/ DUCATO MINIBUS',
#  'MERCEDES-BENZ/BUSSCAR URBANUS U',
#  'PEUGEOT/206 SOLEIL 16',
#  'MERCEDES-BENZ/BUSSCAR ECOSS U',
#  'FIAT/DOBLO AMBULANCIA',
#  'NISSAN/LIVINA 16S',
#  'VOLVO/BUSSCAR VIS BUSS R',
#  'MERCEDES-BENZ/L 1113 CAMINHAO',
#  'IVECO/STRALIHD 490S38TN1',
#  'INTERNATIONAL/9800I 6X2',
#  'IMP/RENAULT MEGANE 2.0 L',
#  'RENAULT/ FLUENCE PRI20A',
#  'CHEVROLET/CHEVETTE HATCH',
#  'VOLKSWAGEN/15.190',
#  'MERCEDES-BENZ/AXOR 2644 S',
#  'I/SEAT CORDOBA',
#  'MERCEDES-BENZ/AXOR 2544 LS',
#  'HYUNDAI/ TUCSON GLS 27L',
#  'VOLKSWAGEN/ PASSAT TURBO',
#  'PEUGEOT/ 307 20S A GRIF',
#  'VOLKSWAGEN/QUANTUM GL',
#  'RENAULT/CLIO RL 1.0 16V',
#  'CHEVROLET/S10 DELUXE 2.2 S',
#  'VOLKSWAGEN/MASCA GRANMIDI EOD O',
#  'MERCEDES-BENZ/MASCA GRANVIA O',
#  'YAMAHA/XTZ250 LANDER',
#  'MERCEDES-BENZ/1218',
#  'TOYOTA/ETIOS HB XS 15',
#  'VOLKSWAGEN/GOL 1.0 TITAN GIV',
#  'FIAT/ELBA 1.6 IE',
#  'VOLVO/VM 330 4X2T',
#  'RENAULT/SANDERO PR1616VA',
#  'VOLKSWAGEN/SAVEIRO AMBULANC 1.6',
#  'YAMAHA/FACTOR PR YBR125K',
#  'VOLKSWAGEN/SAVEIRO 1.8 PLUS',
#  'NISSAN/FRONTIER SE 25 X4',
#  'FORD/ F1000',
#  'FIAT/IDEA HLX FLEX',
#  'VOLKSWAGEN/VOYAGE TL MB S',
#  'YAMAHA/125',
#  'VOLKSWAGEN/24.250CN PMERECHIM 82',
#  'PEUGEOT/ 307 SD16 PR PK',
#  'VOLKSWAGEN/GOL GTI 2000',
#  'VOLKSWAGEN/UP MOVE MB',
#  'VOLVO/MPOLO PARADISO DD',
#  'CITROEN/ C4 PALLAS 20GLM',
#  'CHEVROLET/VERANEIO CUSTOM DELUXE',
#  'VOLKSWAGEN/17.250 E',
#  'SUNDOWN/HUNTER 90',
#  'FIAT/LINEA HLX 1.9',
#  'MITSUBISHI MOTORS/L200 TRITON GLS D',
#  'FORD/F14000 HD',
#  'FORD/ECOSPORT TIT AT 2.0',
#  'HONDA/CBR 600F',
#  'RENAULT/MASTER 8M3 25DCI']

# %% [markdown]
# - **Normalização das colunas do Data Frame de ocorrencia:**

# %%
dataframe_pessoa
# Out:
#              id    pesid  id_veiculo   tipo_veiculo  \
# 0            10   647938      439395      Automóvel
# 1            10   648468      439395      Automóvel
# 2            10   648470      439395      Automóvel
# 3            10   648471      439395      Automóvel
# 4            10  2068191     1204697      Automóvel
# 5            10  2798925     2546752      Camioneta
# 6            10  2894820     2598267      Automóvel
# 7            10  3196042     2759300      Automóvel
# 8            10  4971879    18739144      Automóvel
# 9        173714   446400      328054      Automóvel
# 10       173715   446406      328061      Automóvel
# 11       173715   447594      328059      Automóvel
# 12       173720   446413      328065      Automóvel
# 13       173720   446416      328067      Automóvel
# 14       173720   446419      328069      Automóvel
# 15       173720   446425      328070      Automóvel
# 16       173726   446438      328081      Automóvel
# 17       173726   446441          -1  Não Informado
# 18       173730   446452      328085      Automóvel
# 19       173734   446467      328091      Automóvel
# 20       173734   452279      328093  Não Informado
# 21       173737   446472      328094       Caminhão
# 22       173739   446482      328097      Camioneta
# 23       173739   446486      328098      Automóvel
# 24       173740   446496      328099      Automóvel
# 25       173741   446494      328102    Caminhonete
# 26       173742   446492      328101      Automóvel
# 27       173742   446498          -1  Não Informado
# 28       173743   446500      328104      Camioneta
# 29       173743   446503      328106      Automóvel
# ...         ...      ...         ...            ...
# 4005179  312895   695566          -1    Motocicleta
# 4005180  312905   695573          -1      Automóvel
# 4005181  312905   695572          -1      Automóvel
# 4005182  312915   695582          -1    Caminhonete
# 4005183  312915   695583          -1    Caminhonete
# 4005184  312931   695621          -1    Motocicleta
# 4005185  312940   695638          -1    Motocicleta
# 4005186  312977   695745          -1      Automóvel
# 4005187  312977   695744          -1    Motocicleta
# 4005188  312977   695743          -1    Motocicleta
# 4005189  313034   695912          -1    Motocicleta
# 4005190  313036   695919          -1      Bicicleta
# 4005191  313036   695918          -1      Automóvel
# 4005192  313125   696054          -1      Automóvel
# 4005193  313304   696414          -1     Ciclomotor
# 4005194  313305   696416          -1    Motocicleta
# 4005195  313402   696547          -1    Motocicleta
# 4005196  313946   697074          -1      Automóvel
# 4005197  313946   697073          -1      Automóvel
# 4005198  313946   697072          -1      Automóvel
# 4005199  313957   697101          -1       Motoneta
# 4005200  313957   697100          -1      Automóvel
# 4005201  313977   697116          -1    Motocicleta
# 4005202  314035   697190          -1      Automóvel
# 4005203  314035   697184          -1      Automóvel
# 4005204  314039   697176          -1      Camioneta
# 4005205  314039   697175          -1      Camioneta
# 4005206  314039   697174          -1     Utilitário
# 4005207  314162   697436          -1    Motocicleta
# 4005208  314162   697434          -1    Motocicleta
#
#                                                      marca  \
# 0                                          GM/CLASSIC LIFE
# 1                                          GM/CLASSIC LIFE
# 2                                          GM/CLASSIC LIFE
# 3                                          GM/CLASSIC LIFE
# 4                                 FIAT/UNO MILLE FIRE FLEX
# 5        VW/SAVEIRO GL 1.8                             ...
# 6                                            Não Informado
# 7                                            VW/PARATI 1.6
# 8                                       VW/PARATI 1.8 TOUR
# 9        FIAT/TEMPRA IE                                ...
# 10       FIAT/PALIO EX                                 ...
# 11                                             VW/POLO 2.0
# 12       FIAT/UNO ELECTRONIC                           ...
# 13       GM/KADETT SL/E EFI                            ...
# 14                                RENAULT/CLIO EXP 16 16VH
# 15       GM/VECTRA CD                                  ...
# 16                                FIAT/PALIO WK ADVEN FLEX
# 17                                           Não Informado
# 18       FORD/VERSAILLES 2.0 GL                        ...
# 19                                          FIAT/DOBLO ELX
# 20                                         YAMAHA/YBR 125K
# 21                                VW/15180 EOD NEOBUS MEGA
# 22                                GM/S10 DE LUXE 4.3 E 4X4
# 23       FORD/ESCORT L                                 ...
# 24                                           Não Informado
# 25       GM/S10                                        ...
# 26                                         VW/FOX 1.0 PLUS
# 27                                           Não Informado
# 28                                          VW/SAVEIRO 1.6
# 29       VW/VOYAGE                                     ...
# ...                                                    ...
# 4005179                             HONDA/NXR160 BROS ESDD
# 4005180                           I/CITROEN C4PIC7 THP INT
# 4005181                           I/CITROEN C4PIC7 THP INT
# 4005182                           FIAT/STRADA ADVENTURE CD
# 4005183                           FIAT/STRADA ADVENTURE CD
# 4005184                             HONDA/CG 150 TITAN ESD
# 4005185                              HONDA/CG 150 TITAN KS
# 4005186                                         VW/GOL 1.0
# 4005187                                   HONDA/CG 160 FAN
# 4005188                                   HONDA/CG 160 FAN
# 4005189                                       BMW/S1000 XR
# 4005190                                                NaN
# 4005191                              I/CHEV CRUZE LT HB AT
# 4005192                            FIAT/PALIO FIRE ECONOMY
# 4005193                             I/BASHAN JONNY HYPE 50
# 4005194                                    YAMAHA/YBR 125K
# 4005195                                HONDA/CG 125 FAN KS
# 4005196                              FIAT/PUNTO BLACKMOTIN
# 4005197                              FIAT/PUNTO BLACKMOTIN
# 4005198                            I/FORD FOCUS 2L HC FLEX
# 4005199                                      HONDA/PCX 150
# 4005200                           GM/ASTRA HB 4P ADVANTAGE
# 4005201                                   HONDA/CG 125 FAN
# 4005202                             I/CHEV CRUZE LTZ NB AT
# 4005203                             I/CHEV CRUZE LTZ NB AT
# 4005204                           I/BMW X1 XDRIVE2.8I VM31
# 4005205                           I/BMW X1 XDRIVE2.8I VM31
# 4005206                           I/TOYOTA HILUXSW4 SRV4X4
# 4005207                                   HONDA/CG 125 FAN
# 4005208                                   HONDA/CG 125 FAN
#
#         ano_fabricacao_veiculo tipo_envolvido estado_fisico  idade  \
# 0                         2005       Condutor         Ileso   23.0
# 1                         2005     Passageiro   Ferido Leve   44.0
# 2                         2005     Passageiro   Ferido Leve   10.0
# 3                         2005     Passageiro   Ferido Leve   39.0
# 4                         2008       Condutor         Ileso    NaN
# 5                         1992       Condutor         Ileso    NaN
# 6                         1968       Condutor         Ileso    NaN
# 7                         2008       Condutor         Ileso    NaN
# 8                         2002     Passageiro   Ferido Leve    NaN
# 9                         1996       Condutor         Ileso   59.0
# 10                        1999       Condutor         Ileso   24.0
# 11                        1999       Condutor         Ileso   20.0
# 12                        1995       Condutor         Ileso   34.0
# 13                        1992       Condutor         Ileso   22.0
# 14                        2006       Condutor         Ileso   31.0
# 15                        1999       Condutor         Ileso   32.0
# 16                        2005       Condutor         Ileso   33.0
# 17                      (null)          Autor         Ileso    NaN
# 18                        1993       Condutor         Ileso   27.0
# 19                        2002       Condutor         Ileso   56.0
# 20                                   Condutor  Ferido Grave   24.0
# 21                        2004       Condutor         Ileso   27.0
# 22                        1998       Condutor         Ileso   56.0
# 23                        1994       Condutor         Ileso   38.0
# 24                        2000       Condutor   Ferido Leve   21.0
# 25                        2006       Condutor         Ileso   27.0
# 26                        2006       Condutor         Ileso   51.0
# 27                      (null)       Pedestre         Óbito   34.0
# 28                        1999       Condutor   Ferido Leve   20.0
# 29                        1988       Condutor         Ileso   27.0
# ...                        ...            ...           ...    ...
# 4005179                   2018       Condutor         Óbito    NaN
# 4005180                   2017     Passageiro   Ferido Leve   59.0
# 4005181                   2017       Condutor         Ileso   47.0
# 4005182                   2019       Condutor         Ileso   27.0
# 4005183                   2019     Passageiro  Ferido Grave   29.0
# 4005184                   2015       Condutor  Ferido Grave    NaN
# 4005185                   2009       Condutor   Ferido Leve   51.0
# 4005186                   2007       Condutor         Ileso   35.0
# 4005187                   2018     Passageiro  Ferido Grave   19.0
# 4005188                   2018       Condutor  Ferido Grave   22.0
# 4005189                   2016       Condutor  Ferido Grave   33.0
# 4005190                    NaN       Condutor   Ferido Leve   20.0
# 4005191                   2016       Condutor         Ileso   21.0
# 4005192                   2010       Condutor  Ferido Grave   65.0
# 4005193                   2011       Condutor         Óbito   48.0
# 4005194                   2001       Condutor  Ferido Grave   20.0
# 4005195                   2009       Condutor  Ferido Grave   22.0
# 4005196                   2014     Passageiro   Ferido Leve   38.0
# 4005197                   2014       Condutor   Ferido Leve   35.0
# 4005198                   2011       Condutor         Ileso    NaN
# 4005199                   2018       Condutor   Ferido Leve   29.0
# 4005200                   2011       Condutor         Ileso   31.0
# 4005201                   2008       Condutor  Ferido Grave   61.0
# 4005202                   2018     Passageiro         Ileso    NaN
# 4005203                   2018       Condutor         Ileso    NaN
# 4005204                   2011     Passageiro         Ileso   58.0
# 4005205                   2011       Condutor         Ileso   18.0
# 4005206                   2012       Condutor         Ileso   52.0
# 4005207                   2007     Passageiro   Ferido Leve    NaN
# 4005208                   2007       Condutor  Ferido Grave    NaN
#
#                   sexo   ano
# 0            Masculino  2007
# 1            Masculino  2007
# 2             Feminino  2007
# 3            Masculino  2007
# 4                  NaN  2007
# 5                  NaN  2007
# 6                  NaN  2007
# 7                  NaN  2007
# 8                  NaN  2007
# 9            Masculino  2007
# 10           Masculino  2007
# 11           Masculino  2007
# 12           Masculino  2007
# 13           Masculino  2007
# 14           Masculino  2007
# 15           Masculino  2007
# 16           Masculino  2007
# 17                 NaN  2007
# 18           Masculino  2007
# 19           Masculino  2007
# 20           Masculino  2007
# 21           Masculino  2007
# 22           Masculino  2007
# 23           Masculino  2007
# 24           Masculino  2007
# 25           Masculino  2007
# 26           Masculino  2007
# 27           Masculino  2007
# 28           Masculino  2007
# 29           Masculino  2007
# ...                ...   ...
# 4005179      Masculino  2020
# 4005180       Feminino  2020
# 4005181      Masculino  2020
# 4005182      Masculino  2020
# 4005183      Masculino  2020
# 4005184      Masculino  2020
# 4005185      Masculino  2020
# 4005186      Masculino  2020
# 4005187      Masculino  2020
# 4005188      Masculino  2020
# 4005189      Masculino  2020
# 4005190       Feminino  2020
# 4005191      Masculino  2020
# 4005192      Masculino  2020
# 4005193      Masculino  2020
# 4005194      Masculino  2020
# 4005195      Masculino  2020
# 4005196       Feminino  2020
# 4005197      Masculino  2020
# 4005198  Não Informado  2020
# 4005199       Feminino  2020
# 4005200       Feminino  2020
# 4005201      Masculino  2020
# 4005202      Masculino  2020
# 4005203      Masculino  2020
# 4005204      Masculino  2020
# 4005205      Masculino  2020
# 4005206      Masculino  2020
# 4005207       Feminino  2020
# 4005208      Masculino  2020
#
# [4005209 rows x 11 columns]

# %% [markdown]
# - **Completar com outros valores colunas com valores nulos ou incompletos**

# %%
df_pessoas_2007.idade[df_pessoas_2007.idade.isnull() == True]= 0
df_pessoas_2007.sexo[df_pessoas_2007.sexo.isnull() == True]= 'Inválido'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#adicionar depois os anos em todos os registros de cada dataframe
#tem colunas com dados faltantes ou incompletos

# %% [markdown]
# # União dos Data Frames

# %% [markdown]
# # **Análise exploratória**

# %%
dataframe2017.dtypes
# Out:
# id                          int64
# data_inversa               object
# dia_semana                 object
# horario                    object
# uf                         object
# br                        float64
# km                         object
# municipio                  object
# causa_acidente             object
# tipo_acidente              object
# classificacao_acidente     object
# fase_dia                   object
# sentido_via                object
# condicao_metereologica     object
# tipo_pista                 object
# tracado_via                object
# uso_solo                   object
# pessoas                     int64
# mortos                      int64
# feridos_leves               int64
# feridos_graves              int64
# ilesos                      int64
# ignorados                   int64
# feridos                     int64
# veiculos                    int64
# latitude                   object
# longitude                  object
# regional                   object
# delegacia                  object
# uop                        object
# dtype: object

# %%
dataframe2017['tipo_pista'].value_counts()
# Out:
# Simples     46344
# Dupla       37242
# Múltipla     5977
# Name: tipo_pista, dtype: int64

# %%
dataframe2017['causa_acidente'].value_counts()
# Out:
# Falta de Atenção à Condução                                                       34508
# Velocidade Incompatível                                                           10432
# Ingestão de Álcool                                                                 6448
# Não guardar distância de segurança                                                 5837
# Desobediência às normas de trânsito pelo condutor                                  5219
# Defeito Mecânico no Veículo                                                        4649
# Pista Escorregadia                                                                 4253
# Condutor Dormindo                                                                  3798
# Animais na Pista                                                                   2623
# Falta de Atenção do Pedestre                                                       2390
# Ultrapassagem Indevida                                                             2054
# Avarias e/ou desgaste excessivo no pneu                                            1588
# Defeito na Via                                                                     1422
# Mal Súbito                                                                          972
# Restrição de Visibilidade                                                           884
# Objeto estático sobre o leito carroçável                                            769
# Carga excessiva e/ou mal acondicionada                                              545
# Fenômenos da Natureza                                                               442
# Sinalização da via insuficiente ou inadequada                                       414
# Deficiência ou não Acionamento do Sistema de Iluminação/Sinalização do Veículo      235
# Ingestão de Substâncias Psicoativas                                                  78
# Agressão Externa                                                                      2
# Desobediência às normas de trânsito pelo pedestre                                     1
# Name: causa_acidente, dtype: int64

# %%
dataframe2017['classificacao_acidente'].value_counts()
# Out:
# Com Vítimas Feridas    53699
# Sem Vítimas            30681
# Com Vítimas Fatais      5183
# Name: classificacao_acidente, dtype: int64

# %%
dataframe2017['dia_semana'].value_counts()
# Out:
# sábado           15174
# domingo          14784
# sexta-feira      13849
# segunda-feira    12175
# quinta-feira     11787
# quarta-feira     11029
# terça-feira      10765
# Name: dia_semana, dtype: int64

# %%
dataframe2017['uso_solo'].value_counts()
# Out:
# Não    52863
# Sim    36700
# Name: uso_solo, dtype: int64

# %%
### latitude e longite para plot
dataframe2017['latitude']  = dataframe2017['latitude'].str.replace(',','.')
dataframe2017['longitude']  = dataframe2017['longitude'].str.replace(',','.')

# %%
dataframe2017['latitude'] = dataframe2017['latitude'].astype(float)
dataframe2017['longitude'] = dataframe2017['longitude'].astype(float)

# %% [markdown]
# # **Normalização dos tipos de dados de cada coluna dos dataframes**

# %%
#a maioria está em string e precisa estar em formato data ou numérico
